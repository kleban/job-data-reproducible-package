# %% [markdown]
# # 4.5. Interim Stage (4.5): Region Data Enrichment

# %% [markdown]
# > ## ⚠️ This stage is already completed — you can skip it
# >
# > The pre-built region lookup table **`data/stage_04_5/processed/region_db.pkl`**
# > covers all ~22,000 unique region strings found in the full 2021–2025 dataset.
# > Stage 5 reads this file directly — no reprocessing is required.
# >
# > **Only rerun this notebook if** you have added new vacancy data that contains
# > region strings not yet present in `region_db.pkl` (i.e. strings that return
# > no match during Stage 5 region joining).
# >
# > **Requires an OpenAI API key** if you do rerun. Set `OPENAI_API_KEY` in `notebooks/.env`.

# %% [markdown]
# ## 4.5.1. Description

# %% [markdown]
# Although not a core classification or extraction stage, region enrichment plays a crucial role in improving the quality and usability of the geographic metadata associated with each job advertisement. Many original region fields are unstructured, multilingual, or ambiguous. This step standardizes, expands, and geolocates this information.

# %% [markdown]
# ## 4.5.2. Load packages and configuration

# %% [markdown]
# Enable autoreload, add `code/` to the Python path, and import standard libraries (`general`, `pandas`, `json`, `os`).

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.append("../code")
import general as g
g.clean_memory()
import pandas as pd
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Import `stage1` (for region/click data helpers) and `stage3` (reused for `read_classification_prompt()` and `read_classification_schema()` which work identically for the region enrichment prompt and schema).

# %%
import stage1 as st1
import stage3 as st3

# %% [markdown]
# If you added new data to pipeline - rename stage4_5/region_db.pkl to stage4_5/region_db_PREV.pkl to work with new added region only

# %% [markdown]
# Load the previous region DB snapshot (`region_db_PREV.pkl`) if it exists. This baseline is used to identify only the **new** region strings that need to be submitted to the API — strings already in the previous DB are skipped. Display the loaded DataFrame to confirm shape and columns (`original`, `region`).

# %%
g.Config.STAGE4_5_REGION_PREV_DB_PATH
# Out:
# '../data/stage_04_5/intermediate/region_db_PREV.pkl'

# %%
# Load previous region DB snapshot if it exists; None means all regions are treated as new
if os.path.exists(g.Config.STAGE4_5_REGION_PREV_DB_PATH):
    prev_db = pd.read_pickle(g.Config.STAGE4_5_REGION_PREV_DB_PATH)
else:
    prev_db = None
prev_db
# Out:
#                                               original           city  \
# 0                       Підгороднє, Тернопольская обл.     Pidhorodne
# 1                              Ильинцы, Винницкая обл.       Ilyintsi
# 2                              Бершадь, Винницкая обл.        Bershad
# 3                       Новые Санжары, Полтавская обл.  Novi Sanzhary
# 4                        Кривой Рог, Долгинцевский р-н     Kryvyi Rih
# ...                                                ...            ...
# 25054  Петропілля, Шевченковский р-н, Харьковская обл.    Petropillia
# 25055                         Алтестове, Одесская обл.      Altestove
# 25056                   Червоный Кут, Хмельницкая обл.   Chervony Kut
# 25057                       Владиславка, Киевская обл.    Vladyslavka
# 25058   Новопетровка, Бердянский р-н, Запорожская обл.   Novopetrovka
#
#                        district                 region  country latitude  \
# 0                                      Ternopil Oblast  Ukraine  49.5583
# 1                                     Vinnytsia Oblast  Ukraine  49.1044
# 2                                     Vinnytsia Oblast  Ukraine  48.3647
# 3        Novi Sanzhary District         Poltava Oblast  Ukraine  49.3333
# 4       Dolhyntsevskyi District  Dnipropetrovsk Oblast  Ukraine  47.9105
# ...                         ...                    ...      ...      ...
# 25054  Shevchenkivskyi District         Kharkiv Oblast  Ukraine  49.6972
# 25055                                     Odesa Oblast  Ukraine  46.4825
# 25056                              Khmelnytskyi Oblast  Ukraine  49.4167
# 25057                                      Kyiv Oblast  Ukraine  50.3833
# 25058        Berdyansk District    Zaporizhzhia Oblast  Ukraine  46.8667
#
#       longitude is_remote
# 0       25.5944     false
# 1       29.2131     false
# 2       29.5333     false
# 3       34.3167     false
# 4       33.3918     false
# ...         ...       ...
# 25054   36.3931     false
# 25055   30.7233     false
# 25056   27.0000     false
# 25057   30.5167     false
# 25058   36.8667     false
#
# [14696 rows x 8 columns]

# %% [markdown]
# Load the current merged region DB (`region_db.pkl`) and deduplicate on `original` to ensure each raw region string appears only once. The shape indicates how many unique region strings are already standardised.

# %%
region_df = pd.read_pickle(g.Config.STAGE4_5_REGION_DB_PATH)
#region_df.to_pickle(Config.STAGE4_5_REGION_DB_PATH)

# %%
region_df.drop_duplicates(subset=['original'], keep='first', inplace=True)
region_df.shape
# Out:
# (14696, 8)

# %% [markdown]
# ## 4.5.3. Mergin all region data files into one

# %% [markdown]
# Helper function `merge_pkl_files()` reads all `.pkl` files in the given folder and concatenates them into a single DataFrame. Used to merge all per-day id/region/click count files produced by Stage 1 into one flat table.

# %%
def merge_pkl_files(folder_path):
    pkl_files = [f for f in os.listdir(folder_path) if f.endswith('.pkl')]
    region_df = pd.read_pickle(os.path.join(folder_path,pkl_files[0]))
    for f in pkl_files[1:]:
        id_df = pd.read_pickle(os.path.join( folder_path, f))
        region_df = pd.concat([region_df, id_df], ignore_index=True)
        print(f"Merged {f} with {region_df.shape}")
    return region_df

# %% [markdown]
# Merge all Stage 1 id/region/click pickles from `data/stage_01/intermediate/id_region_click/` into a single DataFrame `id_dfx`. Each row contains a vacancy `id`, its raw `region` string, and `number_of_clicks`. Display the result to confirm the full scope of unique region strings in the dataset.

# %%
id_dfx = merge_pkl_files(g.Config.STAGE1_ID_REGION_NCLICK_PATH)
id_dfx
# Out:
#                      id     region  number_of_clicks        date
# 0   2673941879650338041       Sumy             210.0  2024-01-01
# 1   2829269335131763744   Mykolaiv             412.0  2024-01-01
# 2   2292953494970979965  Chernihiv             428.0  2024-01-01
# 3   8991901255055716088      Rivne             107.0  2024-01-01
# 4   9937412981206494120       Lviv              84.0  2024-01-01
# ..                  ...        ...               ...         ...
# 95  5682536959350677812      Odesa             191.0  2024-01-01
# 96  4745382362973408538   Ternopil             226.0  2024-01-01
# 97  1748822233724604818   Zhytomyr              16.0  2024-01-01
# 98  5942472651725435914     Dnipro             426.0  2024-01-01
# 99  4891541965315671145  Chernihiv             101.0  2024-01-01
#
# [100 rows x 4 columns]

# %% [markdown]
# Sanity check — count vacancies with a null `id`. Should be 0 for a clean dataset.

# %%
id_dfx["id"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Build `prev_list` — the set of region strings already standardised in the previous DB snapshot. Used as a filter in the next cell to find only the truly new strings.

# %%
prev_list = []
if prev_db is not None:
    prev_list = prev_db["original"].tolist()

# %% [markdown]
# Compute `new_regions` — the set difference between all region strings in the dataset and those already standardised. These are the strings that need to be submitted to the OpenAI Batch API. Print to confirm the list is reasonable before proceeding.

# %%
new_regions = list(set(id_dfx["region"]) - set(prev_list))
print(new_regions)
# Out:
# ['Odesa', 'Sumy', 'Khmelnytskyi', 'Kharkiv', 'Uzhhorod', 'Zhytomyr', 'Lutsk', 'Rivne', 'Ivano-Frankivsk', 'Poltava', 'Kyiv', 'Kropyvnytskyi', 'Chernihiv', 'Lviv', 'Zaporizhzhia', 'Dnipro', 'Mykolaiv', 'Cherkasy', 'Ternopil', 'Vinnytsia']

# %% [markdown]
# Wrap the new region strings into a DataFrame and save it as `region_db_NEW.pkl` — this is the input for the Batch API calls below. Then reload and inspect it to confirm contents before building batch files.

# %%
new_regions_db = pd.DataFrame(new_regions, columns=['original']).reset_index(drop=True)
new_regions_db.to_pickle(g.Config.STAGE4_5_REGION_NEW_DB_PATH)

# %%
new_regions_db = pd.read_pickle(g.Config.STAGE4_5_REGION_NEW_DB_PATH)
new_regions_db.shape
# Out:
# (20, 1)

# %%
new_regions_db
# Out:
#            original
# 0             Odesa
# 1              Sumy
# 2      Khmelnytskyi
# 3           Kharkiv
# 4          Uzhhorod
# 5          Zhytomyr
# 6             Lutsk
# 7             Rivne
# 8   Ivano-Frankivsk
# 9           Poltava
# 10             Kyiv
# 11    Kropyvnytskyi
# 12        Chernihiv
# 13             Lviv
# 14     Zaporizhzhia
# 15           Dnipro
# 16         Mykolaiv
# 17         Cherkasy
# 18         Ternopil
# 19        Vinnytsia

# %% [markdown]
# ## 4.5.4. Create batch files for API

# %% [markdown]
# Initialise the OpenAI client using the API key from `Config`. Required for uploading batch files and creating batch jobs.

# %%
# Verify API key is loaded (do not print the actual value)
print("OPENAI_API_KEY loaded:", bool(g.Config.OPENAI_API_KEY))
# Out:
# OPENAI_API_KEY loaded: True

# %%
from openai import OpenAI
client = OpenAI(api_key=g.Config.OPENAI_API_KEY)

# %% [markdown]
# Function `write_region_batch_file()` builds the JSONL batch input file for the OpenAI Batch API. Each line contains one API request with:
# - the raw `original` region string as the user message
# - the region selection function-calling schema (`select_region_schema.json`)
# - the standardisation prompt (`select_region_prompt.txt`)
#
# The file is named `{from}_{to}_{date}.jsonl` to track which slice of new regions it covers. Because the Batch API has a 50,000-request limit per job, large datasets are split into numbered chunks.

# %%
def write_region_batch_file(in_batch_path, subname, region_data_db, response_schema, request_prompt, model = "gpt-4o"):

    batch_path = os.path.join(in_batch_path, f"{subname}.jsonl")
    with open(batch_path, "w", encoding="utf-8") as fout:
        for _, r in region_data_db.iterrows():
            payload = {
                "original": r.loc["original"]
            }
            fout.write(json.dumps({
                "custom_id": "task-id-" + str(_),
                "method": "POST",
                "url": "/v1/chat/completions",
                "body": {
                    "temperature": 0,
                    "model": model,
                    "response_format": { "type": "json_object" },
                    "functions": [ response_schema ],
                    "messages": [
                        { "role": "system","content":request_prompt},
                        { "role" : "user","content":json.dumps(payload, ensure_ascii=False)}
                    ],
                    "function_call": { "name": "selectRegion" }
                }
            }, ensure_ascii=False) + "\n")
    print("✔ built batch input: ", batch_path)
    return batch_path

# %% [markdown]
# Load the region standardisation prompt and function-calling schema using the same helpers as Stage 3. The prompt instructs the LLM to map each raw Ukrainian region string to a standardised English oblast name from a fixed allowed list.

# %%
prompt = st3.read_classification_prompt(g.Config.STAGE4_5_SELECT_REGION_PROMPT)
scheme = st3.read_classification_schema(g.Config.STAGE4_5_SELECT_REGION_SCHEME)

# %% [markdown]
# > Batch files created for OpenAPI are separated custom by analytics for gpt-4o model batch size limitations.

# %% [markdown]
# Check total number of new region strings to decide how to split them into batch chunks. Set `fr` (from index), `to` (to index), and `today` (date tag for the filename) before writing the batch file.

# %%
new_regions_db.shape[0]
# Out:
# 20

# %%
fr = 0
to = 20
today = "010124"

# %% [markdown]
# Write the JSONL batch input file for the current slice `new_regions_db[fr:to]`. The output file is saved to `data/stage_04_5/raw/input/` and its path is stored in `input_batch_path` for the next step. Repeat for each slice until all new regions are covered.

# %%
input_batch_path = write_region_batch_file(g.Config.STAGE4_5_INPUT_BATCH_PATH, f"{fr}_{to}_{today}", new_regions_db[fr:to], scheme, prompt, "gpt-4.1")
# Out:
# ✔ built batch input:  ../data/stage_04_5/raw/input\0_20_010124.jsonl

# %% [markdown]
# ## 4.5.5. Create Job

# %% [markdown]
# Upload the JSONL file to the OpenAI Files API and submit it as a Batch job with a 24-hour completion window. The returned `job` object contains the `job.id` needed to poll for status. This cell submits **one** batch — repeat for each input slice.

# %%
batch_file = client.files.create(
     file=open(input_batch_path, "rb"),
     purpose="batch")

job = client.batches.create(
    input_file_id=batch_file.id,
    endpoint="/v1/chat/completions",
    completion_window="24h")

# %% [markdown]
# Display the job ID. Copy this value and add it to the `job_ids` list in the next section to track it for download.

# %%
job.id
# Out:
# 'batch_69c082a1f0bc819090b98c699c5bc1f2'

# %% [markdown]
# ## 4.5.6. Creating list of batch job_ids

# %% [markdown]
# Accumulate all submitted batch job IDs in the `job_ids` list. After each job completes (typically within minutes to a few hours), uncomment its ID line to include it in the download loop. The `job_id = job.id` cell below captures the most recently created job for convenience.

# %%
job_ids = [
    #'batch_6851621deccc8190a9800829199532ed',  # 1-100 done
    #'batch_68516457699081909d3d32639cae945a',  # 100-120 done
    #'batch_68516502164c8190a1a73932fc154ea9',  # 120-150 done
    #'batch_6851660b2dac8190b51bfd4601850946',  # 150-160 done
    #'batch_68516680d13c8190a174fc7b99274313',  # 160-175 done
    #'batch_685167ad52d881908c180c3c7eb569a2',  # 175-275 done
    #'batch_68516cb4c12c81908aa879839062555e',  # 275-325 done
    #'batch_68517700d4e481909bd58ce082681c16',  # 325-425 done
    #'batch_6851790c5d508190baae21fb86888cdd',  # 425-450 done
    #'batch_68517d7a5c1c819098b12ced6d1b8a51',  # 450-475 done
    #'batch_68517de86f04819087183be1ffe5f44b',  # 475-525 done
    #'batch_68517e7460008190af55eff4333310ab',  # 525-575 done
    #'batch_68517f84b59081909f5bd1267dc3c88b',  # 575-590 done
    #'batch_6851808b0e6c8190b2616836432c7d68',  # 590-595 done
   # 'batch_6852548f703c8190806698b2d8f159e0',  # 595-600 done
   # 'batch_685255435f388190ab1f1d2c52e3dafe',  # 600-610 done
    #'batch_6852603984fc8190967f98aaf859eef5',  # 610-620 done
  #  'batch_685260bf96508190b2e635d58c428a8a',  # 620-700 done
    #'batch_6852615f556c81909744982a9754e120',  # 700-800 done
   # 'batch_685261dec1a48190b1df3dc60f08d9be',   # final batch
    #'batch_6885ca33043c8190aa58dd6c3206141b',   # 0-100 270726
    #'batch_6885cd71769081908ef180cf9d088b75',   #100-200 270726
  #  'batch_6885ce5bd4308190936930c5e0e8012c',    #200-300 270726
    #'batch_6885ce9b8e0481908163d3cd4f898c3e',     #300-400 270726
  #  'batch_6885ced61e64819096b9e8d27b5906d9',    #400-500 270726
  #  'batch_6885cfffa0e88190bc9f5b09a3bced31',    #500-700 270726
  #  'batch_6885d0308ac8819089ebe8ea73b03a23',    #700-1000 270726
  #  'batch_6885d0d167c8819089596d2eb551ced2',   #1000-1300 270726
  #  'batch_6885d1083b848190a0747bec538b75ea',    #1300-1500 270726
   # 'batch_6885d1cec5b88190b9f9632ddd4af1b5',   #1500-1800 270726
   # 'batch_6885d225b8508190bedc3e5fc8540235',   #1800-1900 270726
  #  'batch_6885d29df0bc8190b0e5d59d5daa273e',   #1900-2000 270726
  #  'batch_6885d331e13481909149b98ea1d0d215',   #2000-2100 270726
  #  'batch_6885d365a7fc8190abd94330ce6406f9',   #2100-2200 270726
  #  'batch_6885e2049a408190b34aad75d0bf7b14',    #2200-2250 270726
  #  'batch_6885e356fbb88190a2d8eab879dec4c0',   #2250-2350 270726
  #  'batch_6885e3bec88881909a8e2c769825e621',    #2350-2400 270726
  #  'batch_6885e3f639a081909523464b92c58cb4',    #2400-2700 270726
   # 'batch_6885e47e139c8190a7fdc1a05079b631',    #2700-2750 270726
    #'batch_6885e4a976a08190914695275b5224a0',   #2750-2850 270726
    #'batch_6885e51015d481909c049b1957e1d91b',    #2850-2900 270726
   # 'batch_6885e5d7a0b48190a72d6797665b78c7',   #2900-3000 270726
   # 'batch_6885e5f835b4819099054f4762f1da2b',    #3000-3100 270726
   # 'batch_6885e727677c8190bc5bc5428557e4c2',    #3100-3200 270726
   # 'batch_6885e752765c8190a6820f8628cd5c0d',    #3100-3200 270726
   # 'batch_6885e7b52b8081909327d35d9d73fb4e', #3200-3400 270726
   # 'batch_6885e7dca6c48190a4c3561e7b7f48c2', #3400-3500 270726
    #'batch_6885e87256a0819089728b65cddc4b22', #3500-3600 270726
    #'batch_6885e8acf8448190baa0d661d685ae75', #3600-3700 270726
    #'batch_6885e8ead6f88190ad1456e621389a72', #3700-3800 270726
    #'batch_6885e919de4081908bff705f75ad1f99', #3800-3900 270726
    #'batch_6885ea2d6598819080feebb5d6ecd161', #final
   # 'batch_68e1951711488190bb6bf5432deffc68', #2021-2022 classify start 0-1000
   # 'batch_68e19897729c819084e2657f80ae2ea7',
    #'batch_68e19929a7888190a3eb017ab8c36c8f',#'batch_68e1998d35e08190aa6fa1119ffea708',
    #'batch_68e199a1071481909fb2742b4e4525d2',
    #'batch_68e19bad1ba081909fdbcf200b066a4d', #5-7K
    #'batch_68e20ac0aec08190b3da8aae46a1f6d1', #7-9K
    #'batch_68e20b1561d881908b2587c69f65717b', #9-10K
    #'batch_68e2129722508190a0d8d2023219c9de', #10-12
    #'batch_68e212af3c9c8190940bf4a4455010a3',  #12-14
    #'batch_68e21447559c81909a51bfadc5dd8d93',
    #'batch_68e2146029b48190bb5160fcf02a604a', #16-18
    #'batch_68e216811f2c81908f17bfac75322e79', #18-20
    #'batch_68e21a20f8bc8190b0453f780124715c' #20-22 - final
    'batch_69c082a1f0bc819090b98c699c5bc1f2'
]

# %%
job_id = job.id

# %% [markdown]
# ## 4.5.6. Download output batches

# %% [markdown]
# Poll each job in `job_ids`. When a job's status is `completed`, download the output JSONL from the OpenAI Files API and save it to `data/stage_04_5/processed/output/` using the batch job ID as the filename. Rerun this cell until all jobs are downloaded.

# %%
for job_id in job_ids:
    batch = client.batches.retrieve(job_id)
    if batch.status == "completed":
        result_file_id = batch.output_file_id
        result = client.files.content(result_file_id).content
        with open(os.path.join(g.Config.STAGE4_5_OUTPUT_BATCH_PATH, f"{job_id}.jsonl"), 'wb') as file:
            file.write(result)
        print("Done: comment this :)")
    else:
        print("Status: ", batch.status)
# Out:
# Done: comment this :)

# %% [markdown]
# ## 4.5.7. Combining all output files

# %% [markdown]
# Combine all downloaded output JSONL files from `data/stage_04_5/processed/output/` into a single `combined_output.jsonl`. This merged file is used in the next step to parse all results at once, regardless of how many batch jobs were submitted.

# %%
# Create a list of files in a predefined folder (using Config.STAGE4_5_OUTPUT_BATCH_PATH)
folder_path = g.Config.STAGE4_5_OUTPUT_BATCH_PATH
output_file = '../data/stage_04_5/processed/combined_output.jsonl'
_files = 0
_lines = 0

with open(output_file, 'w', encoding='utf-8') as outfile:
    for filename in os.listdir(folder_path):
        fpath = os.path.join(folder_path, filename)
        _files += 1
        file_path = os.path.join(folder_path, filename)
        print(f"Processing file: {file_path}")
        with open(file_path, 'r', encoding='utf-8') as infile:
            for line in infile:
                _lines += 1
                outfile.write(line)
                print(f"File #{_files}, line #{_lines}")

print(f"All .jsonl files combined into: {output_file}")
# Out:
# Processing file: ../data/stage_04_5/processed/output\batch_69c082a1f0bc819090b98c699c5bc1f2.jsonl
# File #1, line #1
# File #1, line #2
# File #1, line #3
# File #1, line #4
# File #1, line #5
# File #1, line #6
# File #1, line #7
# File #1, line #8
# File #1, line #9
# File #1, line #10
# File #1, line #11
# File #1, line #12
# File #1, line #13
# File #1, line #14
# File #1, line #15
# File #1, line #16
# File #1, line #17
# File #1, line #18
# File #1, line #19
# File #1, line #20
# Processing file: ../data/stage_04_5/processed/output\batch_68e19929a7888190a3eb017ab8c36c8f.jsonl
# File #2, line #21
# File #2, line #22
# File #2, line #23
# File #2, line #24
# File #2, line #25
# File #2, line #26
# File #2, line #27
# File #2, line #28
# File #2, line #29
# File #2, line #30
# File #2, line #31
# File #2, line #32
# File #2, line #33
# File #2, line #34
# File #2, line #35
# File #2, line #36
# File #2, line #37
# File #2, line #38
# File #2, line #39
# File #2, line #40
# File #2, line #41
# File #2, line #42
# File #2, line #43
# File #2, line #44
# File #2, line #45
# File #2, line #46
# File #2, line #47
# File #2, line #48
# File #2, line #49
# File #2, line #50
# File #2, line #51
# File #2, line #52
# File #2, line #53
# File #2, line #54
# File #2, line #55
# File #2, line #56
# File #2, line #57
# File #2, line #58
# File #2, line #59
# File #2, line #60
# File #2, line #61
# File #2, line #62
# File #2, line #63
# File #2, line #64
# File #2, line #65
# File #2, line #66
# File #2, line #67
# File #2, line #68
# File #2, line #69
# File #2, line #70
# File #2, line #71
# File #2, line #72
# File #2, line #73
# File #2, line #74
# File #2, line #75
# File #2, line #76
# File #2, line #77
# File #2, line #78
# File #2, line #79
# File #2, line #80
# File #2, line #81
# File #2, line #82
# File #2, line #83
# File #2, line #84
# File #2, line #85
# File #2, line #86
# File #2, line #87
# File #2, line #88
# File #2, line #89
# File #2, line #90
# File #2, line #91
# File #2, line #92
# File #2, line #93
# File #2, line #94
# File #2, line #95
# File #2, line #96
# File #2, line #97
# File #2, line #98
# File #2, line #99
# File #2, line #100
# File #2, line #101
# File #2, line #102
# File #2, line #103
# File #2, line #104
# File #2, line #105
# File #2, line #106
# File #2, line #107
# File #2, line #108
# File #2, line #109
# File #2, line #110
# File #2, line #111
# File #2, line #112
# File #2, line #113
# File #2, line #114
# File #2, line #115
# File #2, line #116
# File #2, line #117
# File #2, line #118
# File #2, line #119
# File #2, line #120
# File #2, line #121
# File #2, line #122
# File #2, line #123
# File #2, line #124
# File #2, line #125
# File #2, line #126
# File #2, line #127
# File #2, line #128
# File #2, line #129
# File #2, line #130
# File #2, line #131
# File #2, line #132
# File #2, line #133
# File #2, line #134
# File #2, line #135
# File #2, line #136
# File #2, line #137
# File #2, line #138
# File #2, line #139
# File #2, line #140
# File #2, line #141
# File #2, line #142
# File #2, line #143
# File #2, line #144
# File #2, line #145
# File #2, line #146
# File #2, line #147
# File #2, line #148
# File #2, line #149
# File #2, line #150
# File #2, line #151
# File #2, line #152
# File #2, line #153
# File #2, line #154
# File #2, line #155
# File #2, line #156
# File #2, line #157
# File #2, line #158
# File #2, line #159
# File #2, line #160
# File #2, line #161
# File #2, line #162
# File #2, line #163
# File #2, line #164
# File #2, line #165
# File #2, line #166
# File #2, line #167
# File #2, line #168
# File #2, line #169
# File #2, line #170
# File #2, line #171
# File #2, line #172
# File #2, line #173
# File #2, line #174
# File #2, line #175
# File #2, line #176
# File #2, line #177
# File #2, line #178
# File #2, line #179
# File #2, line #180
# File #2, line #181
# File #2, line #182
# File #2, line #183
# File #2, line #184
# File #2, line #185
# File #2, line #186
# File #2, line #187
# File #2, line #188
# File #2, line #189
# File #2, line #190
# File #2, line #191
# File #2, line #192
# File #2, line #193
# File #2, line #194
# File #2, line #195
# File #2, line #196
# File #2, line #197
# File #2, line #198
# File #2, line #199
# File #2, line #200
# File #2, line #201
# File #2, line #202
# File #2, line #203
# File #2, line #204
# File #2, line #205
# File #2, line #206
# File #2, line #207
# File #2, line #208
# File #2, line #209
# File #2, line #210
# File #2, line #211
# File #2, line #212
# File #2, line #213
# File #2, line #214
# File #2, line #215
# File #2, line #216
# File #2, line #217
# File #2, line #218
# File #2, line #219
# File #2, line #220
# File #2, line #221
# File #2, line #222
# File #2, line #223
# File #2, line #224
# File #2, line #225
# File #2, line #226
# File #2, line #227
# File #2, line #228
# File #2, line #229
# File #2, line #230
# File #2, line #231
# File #2, line #232
# File #2, line #233
# File #2, line #234
# File #2, line #235
# File #2, line #236
# File #2, line #237
# File #2, line #238
# File #2, line #239
# File #2, line #240
# File #2, line #241
# File #2, line #242
# File #2, line #243
# File #2, line #244
# File #2, line #245
# File #2, line #246
# File #2, line #247
# File #2, line #248
# File #2, line #249
# File #2, line #250
# File #2, line #251
# File #2, line #252
# File #2, line #253
# File #2, line #254
# File #2, line #255
# File #2, line #256
# File #2, line #257
# File #2, line #258
# File #2, line #259
# File #2, line #260
# File #2, line #261
# File #2, line #262
# File #2, line #263
# File #2, line #264
# File #2, line #265
# File #2, line #266
# File #2, line #267
# File #2, line #268
# File #2, line #269
# File #2, line #270
# File #2, line #271
# File #2, line #272
# File #2, line #273
# File #2, line #274
# File #2, line #275
# File #2, line #276
# File #2, line #277
# File #2, line #278
# File #2, line #279
# File #2, line #280
# File #2, line #281
# File #2, line #282
# File #2, line #283
# File #2, line #284
# File #2, line #285
# File #2, line #286
# File #2, line #287
# File #2, line #288
# File #2, line #289
# File #2, line #290
# File #2, line #291
# File #2, line #292
# File #2, line #293
# File #2, line #294
# File #2, line #295
# File #2, line #296
# File #2, line #297
# File #2, line #298
# File #2, line #299
# File #2, line #300
# File #2, line #301
# File #2, line #302
# File #2, line #303
# File #2, line #304
# File #2, line #305
# File #2, line #306
# File #2, line #307
# File #2, line #308
# File #2, line #309
# File #2, line #310
# File #2, line #311
# File #2, line #312
# File #2, line #313
# File #2, line #314
# File #2, line #315
# File #2, line #316
# File #2, line #317
# File #2, line #318
# File #2, line #319
# File #2, line #320
# File #2, line #321
# File #2, line #322
# File #2, line #323
# File #2, line #324
# File #2, line #325
# File #2, line #326
# File #2, line #327
# File #2, line #328
# File #2, line #329
# File #2, line #330
# File #2, line #331
# File #2, line #332
# File #2, line #333
# File #2, line #334
# File #2, line #335
# File #2, line #336
# File #2, line #337
# File #2, line #338
# File #2, line #339
# File #2, line #340
# File #2, line #341
# File #2, line #342
# File #2, line #343
# File #2, line #344
# File #2, line #345
# File #2, line #346
# File #2, line #347
# File #2, line #348
# File #2, line #349
# File #2, line #350
# File #2, line #351
# File #2, line #352
# File #2, line #353
# File #2, line #354
# File #2, line #355
# File #2, line #356
# File #2, line #357
# File #2, line #358
# File #2, line #359
# File #2, line #360
# File #2, line #361
# File #2, line #362
# File #2, line #363
# File #2, line #364
# File #2, line #365
# File #2, line #366
# File #2, line #367
# File #2, line #368
# File #2, line #369
# File #2, line #370
# File #2, line #371
# File #2, line #372
# File #2, line #373
# File #2, line #374
# File #2, line #375
# File #2, line #376
# File #2, line #377
# File #2, line #378
# File #2, line #379
# File #2, line #380
# File #2, line #381
# File #2, line #382
# File #2, line #383
# File #2, line #384
# File #2, line #385
# File #2, line #386
# File #2, line #387
# File #2, line #388
# File #2, line #389
# File #2, line #390
# File #2, line #391
# File #2, line #392
# File #2, line #393
# File #2, line #394
# File #2, line #395
# File #2, line #396
# File #2, line #397
# File #2, line #398
# File #2, line #399
# File #2, line #400
# File #2, line #401
# File #2, line #402
# File #2, line #403
# File #2, line #404
# File #2, line #405
# File #2, line #406
# File #2, line #407
# File #2, line #408
# File #2, line #409
# File #2, line #410
# File #2, line #411
# File #2, line #412
# File #2, line #413
# File #2, line #414
# File #2, line #415
# File #2, line #416
# File #2, line #417
# File #2, line #418
# File #2, line #419
# File #2, line #420
# File #2, line #421
# File #2, line #422
# File #2, line #423
# File #2, line #424
# File #2, line #425
# File #2, line #426
# File #2, line #427
# File #2, line #428
# File #2, line #429
# File #2, line #430
# File #2, line #431
# File #2, line #432
# File #2, line #433
# File #2, line #434
# File #2, line #435
# File #2, line #436
# File #2, line #437
# File #2, line #438
# File #2, line #439
# File #2, line #440
# File #2, line #441
# File #2, line #442
# File #2, line #443
# File #2, line #444
# File #2, line #445
# File #2, line #446
# File #2, line #447
# File #2, line #448
# File #2, line #449
# File #2, line #450
# File #2, line #451
# File #2, line #452
# File #2, line #453
# File #2, line #454
# File #2, line #455
# File #2, line #456
# File #2, line #457
# File #2, line #458
# File #2, line #459
# File #2, line #460
# File #2, line #461
# File #2, line #462
# File #2, line #463
# File #2, line #464
# File #2, line #465
# File #2, line #466
# File #2, line #467
# File #2, line #468
# File #2, line #469
# File #2, line #470
# File #2, line #471
# File #2, line #472
# File #2, line #473
# File #2, line #474
# File #2, line #475
# File #2, line #476
# File #2, line #477
# File #2, line #478
# File #2, line #479
# File #2, line #480
# File #2, line #481
# File #2, line #482
# File #2, line #483
# File #2, line #484
# File #2, line #485
# File #2, line #486
# File #2, line #487
# File #2, line #488
# File #2, line #489
# File #2, line #490
# File #2, line #491
# File #2, line #492
# File #2, line #493
# File #2, line #494
# File #2, line #495
# File #2, line #496
# File #2, line #497
# File #2, line #498
# File #2, line #499
# File #2, line #500
# File #2, line #501
# File #2, line #502
# File #2, line #503
# File #2, line #504
# File #2, line #505
# File #2, line #506
# File #2, line #507
# File #2, line #508
# File #2, line #509
# File #2, line #510
# File #2, line #511
# File #2, line #512
# File #2, line #513
# File #2, line #514
# File #2, line #515
# File #2, line #516
# File #2, line #517
# File #2, line #518
# File #2, line #519
# File #2, line #520
# File #2, line #521
# File #2, line #522
# File #2, line #523
# File #2, line #524
# File #2, line #525
# File #2, line #526
# File #2, line #527
# File #2, line #528
# File #2, line #529
# File #2, line #530
# File #2, line #531
# File #2, line #532
# File #2, line #533
# File #2, line #534
# File #2, line #535
# File #2, line #536
# File #2, line #537
# File #2, line #538
# File #2, line #539
# File #2, line #540
# File #2, line #541
# File #2, line #542
# File #2, line #543
# File #2, line #544
# File #2, line #545
# File #2, line #546
# File #2, line #547
# File #2, line #548
# File #2, line #549
# File #2, line #550
# File #2, line #551
# File #2, line #552
# File #2, line #553
# File #2, line #554
# File #2, line #555
# File #2, line #556
# File #2, line #557
# File #2, line #558
# File #2, line #559
# File #2, line #560
# File #2, line #561
# File #2, line #562
# File #2, line #563
# File #2, line #564
# File #2, line #565
# File #2, line #566
# File #2, line #567
# File #2, line #568
# File #2, line #569
# File #2, line #570
# File #2, line #571
# File #2, line #572
# File #2, line #573
# File #2, line #574
# File #2, line #575
# File #2, line #576
# File #2, line #577
# File #2, line #578
# File #2, line #579
# File #2, line #580
# File #2, line #581
# File #2, line #582
# File #2, line #583
# File #2, line #584
# File #2, line #585
# File #2, line #586
# File #2, line #587
# File #2, line #588
# File #2, line #589
# File #2, line #590
# File #2, line #591
# File #2, line #592
# File #2, line #593
# File #2, line #594
# File #2, line #595
# File #2, line #596
# File #2, line #597
# File #2, line #598
# File #2, line #599
# File #2, line #600
# File #2, line #601
# File #2, line #602
# File #2, line #603
# File #2, line #604
# File #2, line #605
# File #2, line #606
# File #2, line #607
# File #2, line #608
# File #2, line #609
# File #2, line #610
# File #2, line #611
# File #2, line #612
# File #2, line #613
# File #2, line #614
# File #2, line #615
# File #2, line #616
# File #2, line #617
# File #2, line #618
# File #2, line #619
# File #2, line #620
# File #2, line #621
# File #2, line #622
# File #2, line #623
# File #2, line #624
# File #2, line #625
# File #2, line #626
# File #2, line #627
# File #2, line #628
# File #2, line #629
# File #2, line #630
# File #2, line #631
# File #2, line #632
# File #2, line #633
# File #2, line #634
# File #2, line #635
# File #2, line #636
# File #2, line #637
# File #2, line #638
# File #2, line #639
# File #2, line #640
# File #2, line #641
# File #2, line #642
# File #2, line #643
# File #2, line #644
# File #2, line #645
# File #2, line #646
# File #2, line #647
# File #2, line #648
# File #2, line #649
# File #2, line #650
# File #2, line #651
# File #2, line #652
# File #2, line #653
# File #2, line #654
# File #2, line #655
# File #2, line #656
# File #2, line #657
# File #2, line #658
# File #2, line #659
# File #2, line #660
# File #2, line #661
# File #2, line #662
# File #2, line #663
# File #2, line #664
# File #2, line #665
# File #2, line #666
# File #2, line #667
# File #2, line #668
# File #2, line #669
# File #2, line #670
# File #2, line #671
# File #2, line #672
# File #2, line #673
# File #2, line #674
# File #2, line #675
# File #2, line #676
# File #2, line #677
# File #2, line #678
# File #2, line #679
# File #2, line #680
# File #2, line #681
# File #2, line #682
# File #2, line #683
# File #2, line #684
# File #2, line #685
# File #2, line #686
# File #2, line #687
# File #2, line #688
# File #2, line #689
# File #2, line #690
# File #2, line #691
# File #2, line #692
# File #2, line #693
# File #2, line #694
# File #2, line #695
# File #2, line #696
# File #2, line #697
# File #2, line #698
# File #2, line #699
# File #2, line #700
# File #2, line #701
# File #2, line #702
# File #2, line #703
# File #2, line #704
# File #2, line #705
# File #2, line #706
# File #2, line #707
# File #2, line #708
# File #2, line #709
# File #2, line #710
# File #2, line #711
# File #2, line #712
# File #2, line #713
# File #2, line #714
# File #2, line #715
# File #2, line #716
# File #2, line #717
# File #2, line #718
# File #2, line #719
# File #2, line #720
# File #2, line #721
# File #2, line #722
# File #2, line #723
# File #2, line #724
# File #2, line #725
# File #2, line #726
# File #2, line #727
# File #2, line #728
# File #2, line #729
# File #2, line #730
# File #2, line #731
# File #2, line #732
# File #2, line #733
# File #2, line #734
# File #2, line #735
# File #2, line #736
# File #2, line #737
# File #2, line #738
# File #2, line #739
# File #2, line #740
# File #2, line #741
# File #2, line #742
# File #2, line #743
# File #2, line #744
# File #2, line #745
# File #2, line #746
# File #2, line #747
# File #2, line #748
# File #2, line #749
# File #2, line #750
# File #2, line #751
# File #2, line #752
# File #2, line #753
# File #2, line #754
# File #2, line #755
# File #2, line #756
# File #2, line #757
# File #2, line #758
# File #2, line #759
# File #2, line #760
# File #2, line #761
# File #2, line #762
# File #2, line #763
# File #2, line #764
# File #2, line #765
# File #2, line #766
# File #2, line #767
# File #2, line #768
# File #2, line #769
# File #2, line #770
# File #2, line #771
# File #2, line #772
# File #2, line #773
# File #2, line #774
# File #2, line #775
# File #2, line #776
# File #2, line #777
# File #2, line #778
# File #2, line #779
# File #2, line #780
# File #2, line #781
# File #2, line #782
# File #2, line #783
# File #2, line #784
# File #2, line #785
# File #2, line #786
# File #2, line #787
# File #2, line #788
# File #2, line #789
# File #2, line #790
# File #2, line #791
# File #2, line #792
# File #2, line #793
# File #2, line #794
# File #2, line #795
# File #2, line #796
# File #2, line #797
# File #2, line #798
# File #2, line #799
# File #2, line #800
# File #2, line #801
# File #2, line #802
# File #2, line #803
# File #2, line #804
# File #2, line #805
# File #2, line #806
# File #2, line #807
# File #2, line #808
# File #2, line #809
# File #2, line #810
# File #2, line #811
# File #2, line #812
# File #2, line #813
# File #2, line #814
# File #2, line #815
# File #2, line #816
# File #2, line #817
# File #2, line #818
# File #2, line #819
# File #2, line #820
# File #2, line #821
# File #2, line #822
# File #2, line #823
# File #2, line #824
# File #2, line #825
# File #2, line #826
# File #2, line #827
# File #2, line #828
# File #2, line #829
# File #2, line #830
# File #2, line #831
# File #2, line #832
# File #2, line #833
# File #2, line #834
# File #2, line #835
# File #2, line #836
# File #2, line #837
# File #2, line #838
# File #2, line #839
# File #2, line #840
# File #2, line #841
# File #2, line #842
# File #2, line #843
# File #2, line #844
# File #2, line #845
# File #2, line #846
# File #2, line #847
# File #2, line #848
# File #2, line #849
# File #2, line #850
# File #2, line #851
# File #2, line #852
# File #2, line #853
# File #2, line #854
# File #2, line #855
# File #2, line #856
# File #2, line #857
# File #2, line #858
# File #2, line #859
# File #2, line #860
# File #2, line #861
# File #2, line #862
# File #2, line #863
# File #2, line #864
# File #2, line #865
# File #2, line #866
# File #2, line #867
# File #2, line #868
# File #2, line #869
# File #2, line #870
# File #2, line #871
# File #2, line #872
# File #2, line #873
# File #2, line #874
# File #2, line #875
# File #2, line #876
# File #2, line #877
# File #2, line #878
# File #2, line #879
# File #2, line #880
# File #2, line #881
# File #2, line #882
# File #2, line #883
# File #2, line #884
# File #2, line #885
# File #2, line #886
# File #2, line #887
# File #2, line #888
# File #2, line #889
# File #2, line #890
# File #2, line #891
# File #2, line #892
# File #2, line #893
# File #2, line #894
# File #2, line #895
# File #2, line #896
# File #2, line #897
# File #2, line #898
# File #2, line #899
# File #2, line #900
# File #2, line #901
# File #2, line #902
# File #2, line #903
# File #2, line #904
# File #2, line #905
# File #2, line #906
# File #2, line #907
# File #2, line #908
# File #2, line #909
# File #2, line #910
# File #2, line #911
# File #2, line #912
# File #2, line #913
# File #2, line #914
# File #2, line #915
# File #2, line #916
# File #2, line #917
# File #2, line #918
# File #2, line #919
# File #2, line #920
# File #2, line #921
# File #2, line #922
# File #2, line #923
# File #2, line #924
# File #2, line #925
# File #2, line #926
# File #2, line #927
# File #2, line #928
# File #2, line #929
# File #2, line #930
# File #2, line #931
# File #2, line #932
# File #2, line #933
# File #2, line #934
# File #2, line #935
# File #2, line #936
# File #2, line #937
# File #2, line #938
# File #2, line #939
# File #2, line #940
# File #2, line #941
# File #2, line #942
# File #2, line #943
# File #2, line #944
# File #2, line #945
# File #2, line #946
# File #2, line #947
# File #2, line #948
# File #2, line #949
# File #2, line #950
# File #2, line #951
# File #2, line #952
# File #2, line #953
# File #2, line #954
# File #2, line #955
# File #2, line #956
# File #2, line #957
# File #2, line #958
# File #2, line #959
# File #2, line #960
# File #2, line #961
# File #2, line #962
# File #2, line #963
# File #2, line #964
# File #2, line #965
# File #2, line #966
# File #2, line #967
# File #2, line #968
# File #2, line #969
# File #2, line #970
# File #2, line #971
# File #2, line #972
# File #2, line #973
# File #2, line #974
# File #2, line #975
# File #2, line #976
# File #2, line #977
# File #2, line #978
# File #2, line #979
# File #2, line #980
# File #2, line #981
# File #2, line #982
# File #2, line #983
# File #2, line #984
# File #2, line #985
# File #2, line #986
# File #2, line #987
# File #2, line #988
# File #2, line #989
# File #2, line #990
# File #2, line #991
# File #2, line #992
# File #2, line #993
# File #2, line #994
# File #2, line #995
# File #2, line #996
# File #2, line #997
# File #2, line #998
# File #2, line #999
# File #2, line #1000
# File #2, line #1001
# File #2, line #1002
# File #2, line #1003
# File #2, line #1004
# File #2, line #1005
# File #2, line #1006
# File #2, line #1007
# File #2, line #1008
# File #2, line #1009
# File #2, line #1010
# File #2, line #1011
# File #2, line #1012
# File #2, line #1013
# File #2, line #1014
# File #2, line #1015
# File #2, line #1016
# File #2, line #1017
# File #2, line #1018
# File #2, line #1019
# File #2, line #1020
# Processing file: ../data/stage_04_5/processed/output\batch_68e216811f2c81908f17bfac75322e79.jsonl
# File #3, line #1021
# File #3, line #1022
# File #3, line #1023
# File #3, line #1024
# File #3, line #1025
# File #3, line #1026
# File #3, line #1027
# File #3, line #1028
# File #3, line #1029
# File #3, line #1030
# File #3, line #1031
# File #3, line #1032
# File #3, line #1033
# File #3, line #1034
# File #3, line #1035
# File #3, line #1036
# File #3, line #1037
# File #3, line #1038
# File #3, line #1039
# File #3, line #1040
# File #3, line #1041
# File #3, line #1042
# File #3, line #1043
# File #3, line #1044
# File #3, line #1045
# File #3, line #1046
# File #3, line #1047
# File #3, line #1048
# File #3, line #1049
# File #3, line #1050
# File #3, line #1051
# File #3, line #1052
# File #3, line #1053
# File #3, line #1054
# File #3, line #1055
# File #3, line #1056
# File #3, line #1057
# File #3, line #1058
# File #3, line #1059
# File #3, line #1060
# File #3, line #1061
# File #3, line #1062
# File #3, line #1063
# File #3, line #1064
# File #3, line #1065
# File #3, line #1066
# File #3, line #1067
# File #3, line #1068
# File #3, line #1069
# File #3, line #1070
# File #3, line #1071
# File #3, line #1072
# File #3, line #1073
# File #3, line #1074
# File #3, line #1075
# File #3, line #1076
# File #3, line #1077
# File #3, line #1078
# File #3, line #1079
# File #3, line #1080
# File #3, line #1081
# File #3, line #1082
# File #3, line #1083
# File #3, line #1084
# File #3, line #1085
# File #3, line #1086
# File #3, line #1087
# File #3, line #1088
# File #3, line #1089
# File #3, line #1090
# File #3, line #1091
# File #3, line #1092
# File #3, line #1093
# File #3, line #1094
# File #3, line #1095
# File #3, line #1096
# File #3, line #1097
# File #3, line #1098
# File #3, line #1099
# File #3, line #1100
# File #3, line #1101
# File #3, line #1102
# File #3, line #1103
# File #3, line #1104
# File #3, line #1105
# File #3, line #1106
# File #3, line #1107
# File #3, line #1108
# File #3, line #1109
# File #3, line #1110
# File #3, line #1111
# File #3, line #1112
# File #3, line #1113
# File #3, line #1114
# File #3, line #1115
# File #3, line #1116
# File #3, line #1117
# File #3, line #1118
# File #3, line #1119
# File #3, line #1120
# File #3, line #1121
# File #3, line #1122
# File #3, line #1123
# File #3, line #1124
# File #3, line #1125
# File #3, line #1126
# File #3, line #1127
# File #3, line #1128
# File #3, line #1129
# File #3, line #1130
# File #3, line #1131
# File #3, line #1132
# File #3, line #1133
# File #3, line #1134
# File #3, line #1135
# File #3, line #1136
# File #3, line #1137
# File #3, line #1138
# File #3, line #1139
# File #3, line #1140
# File #3, line #1141
# File #3, line #1142
# File #3, line #1143
# File #3, line #1144
# File #3, line #1145
# File #3, line #1146
# File #3, line #1147
# File #3, line #1148
# File #3, line #1149
# File #3, line #1150
# File #3, line #1151
# File #3, line #1152
# File #3, line #1153
# File #3, line #1154
# File #3, line #1155
# File #3, line #1156
# File #3, line #1157
# File #3, line #1158
# File #3, line #1159
# File #3, line #1160
# File #3, line #1161
# File #3, line #1162
# File #3, line #1163
# File #3, line #1164
# File #3, line #1165
# File #3, line #1166
# File #3, line #1167
# File #3, line #1168
# File #3, line #1169
# File #3, line #1170
# File #3, line #1171
# File #3, line #1172
# File #3, line #1173
# File #3, line #1174
# File #3, line #1175
# File #3, line #1176
# File #3, line #1177
# File #3, line #1178
# File #3, line #1179
# File #3, line #1180
# File #3, line #1181
# File #3, line #1182
# File #3, line #1183
# File #3, line #1184
# File #3, line #1185
# File #3, line #1186
# File #3, line #1187
# File #3, line #1188
# File #3, line #1189
# File #3, line #1190
# File #3, line #1191
# File #3, line #1192
# File #3, line #1193
# File #3, line #1194
# File #3, line #1195
# File #3, line #1196
# File #3, line #1197
# File #3, line #1198
# File #3, line #1199
# File #3, line #1200
# File #3, line #1201
# File #3, line #1202
# File #3, line #1203
# File #3, line #1204
# File #3, line #1205
# File #3, line #1206
# File #3, line #1207
# File #3, line #1208
# File #3, line #1209
# File #3, line #1210
# File #3, line #1211
# File #3, line #1212
# File #3, line #1213
# File #3, line #1214
# File #3, line #1215
# File #3, line #1216
# File #3, line #1217
# File #3, line #1218
# File #3, line #1219
# File #3, line #1220
# File #3, line #1221
# File #3, line #1222
# File #3, line #1223
# File #3, line #1224
# File #3, line #1225
# File #3, line #1226
# File #3, line #1227
# File #3, line #1228
# File #3, line #1229
# File #3, line #1230
# File #3, line #1231
# File #3, line #1232
# File #3, line #1233
# File #3, line #1234
# File #3, line #1235
# File #3, line #1236
# File #3, line #1237
# File #3, line #1238
# File #3, line #1239
# File #3, line #1240
# File #3, line #1241
# File #3, line #1242
# File #3, line #1243
# File #3, line #1244
# File #3, line #1245
# File #3, line #1246
# File #3, line #1247
# File #3, line #1248
# File #3, line #1249
# File #3, line #1250
# File #3, line #1251
# File #3, line #1252
# File #3, line #1253
# File #3, line #1254
# File #3, line #1255
# File #3, line #1256
# File #3, line #1257
# File #3, line #1258
# File #3, line #1259
# File #3, line #1260
# File #3, line #1261
# File #3, line #1262
# File #3, line #1263
# File #3, line #1264
# File #3, line #1265
# File #3, line #1266
# File #3, line #1267
# File #3, line #1268
# File #3, line #1269
# File #3, line #1270
# File #3, line #1271
# File #3, line #1272
# File #3, line #1273
# File #3, line #1274
# File #3, line #1275
# File #3, line #1276
# File #3, line #1277
# File #3, line #1278
# File #3, line #1279
# File #3, line #1280
# File #3, line #1281
# File #3, line #1282
# File #3, line #1283
# File #3, line #1284
# File #3, line #1285
# File #3, line #1286
# File #3, line #1287
# File #3, line #1288
# File #3, line #1289
# File #3, line #1290
# File #3, line #1291
# File #3, line #1292
# File #3, line #1293
# File #3, line #1294
# File #3, line #1295
# File #3, line #1296
# File #3, line #1297
# File #3, line #1298
# File #3, line #1299
# File #3, line #1300
# File #3, line #1301
# File #3, line #1302
# File #3, line #1303
# File #3, line #1304
# File #3, line #1305
# File #3, line #1306
# File #3, line #1307
# File #3, line #1308
# File #3, line #1309
# File #3, line #1310
# File #3, line #1311
# File #3, line #1312
# File #3, line #1313
# File #3, line #1314
# File #3, line #1315
# File #3, line #1316
# File #3, line #1317
# File #3, line #1318
# File #3, line #1319
# File #3, line #1320
# File #3, line #1321
# File #3, line #1322
# File #3, line #1323
# File #3, line #1324
# File #3, line #1325
# File #3, line #1326
# File #3, line #1327
# File #3, line #1328
# File #3, line #1329
# File #3, line #1330
# File #3, line #1331
# File #3, line #1332
# File #3, line #1333
# File #3, line #1334
# File #3, line #1335
# File #3, line #1336
# File #3, line #1337
# File #3, line #1338
# File #3, line #1339
# File #3, line #1340
# File #3, line #1341
# File #3, line #1342
# File #3, line #1343
# File #3, line #1344
# File #3, line #1345
# File #3, line #1346
# File #3, line #1347
# File #3, line #1348
# File #3, line #1349
# File #3, line #1350
# File #3, line #1351
# File #3, line #1352
# File #3, line #1353
# File #3, line #1354
# File #3, line #1355
# File #3, line #1356
# File #3, line #1357
# File #3, line #1358
# File #3, line #1359
# File #3, line #1360
# File #3, line #1361
# File #3, line #1362
# File #3, line #1363
# File #3, line #1364
# File #3, line #1365
# File #3, line #1366
# File #3, line #1367
# File #3, line #1368
# File #3, line #1369
# File #3, line #1370
# File #3, line #1371
# File #3, line #1372
# File #3, line #1373
# File #3, line #1374
# File #3, line #1375
# File #3, line #1376
# File #3, line #1377
# File #3, line #1378
# File #3, line #1379
# File #3, line #1380
# File #3, line #1381
# File #3, line #1382
# File #3, line #1383
# File #3, line #1384
# File #3, line #1385
# File #3, line #1386
# File #3, line #1387
# File #3, line #1388
# File #3, line #1389
# File #3, line #1390
# File #3, line #1391
# File #3, line #1392
# File #3, line #1393
# File #3, line #1394
# File #3, line #1395
# File #3, line #1396
# File #3, line #1397
# File #3, line #1398
# File #3, line #1399
# File #3, line #1400
# File #3, line #1401
# File #3, line #1402
# File #3, line #1403
# File #3, line #1404
# File #3, line #1405
# File #3, line #1406
# File #3, line #1407
# File #3, line #1408
# File #3, line #1409
# File #3, line #1410
# File #3, line #1411
# File #3, line #1412
# File #3, line #1413
# File #3, line #1414
# File #3, line #1415
# File #3, line #1416
# File #3, line #1417
# File #3, line #1418
# File #3, line #1419
# File #3, line #1420
# File #3, line #1421
# File #3, line #1422
# File #3, line #1423
# File #3, line #1424
# File #3, line #1425
# File #3, line #1426
# File #3, line #1427
# File #3, line #1428
# File #3, line #1429
# File #3, line #1430
# File #3, line #1431
# File #3, line #1432
# File #3, line #1433
# File #3, line #1434
# File #3, line #1435
# File #3, line #1436
# File #3, line #1437
# File #3, line #1438
# File #3, line #1439
# File #3, line #1440
# File #3, line #1441
# File #3, line #1442
# File #3, line #1443
# File #3, line #1444
# File #3, line #1445
# File #3, line #1446
# File #3, line #1447
# File #3, line #1448
# File #3, line #1449
# File #3, line #1450
# File #3, line #1451
# File #3, line #1452
# File #3, line #1453
# File #3, line #1454
# File #3, line #1455
# File #3, line #1456
# File #3, line #1457
# File #3, line #1458
# File #3, line #1459
# File #3, line #1460
# File #3, line #1461
# File #3, line #1462
# File #3, line #1463
# File #3, line #1464
# File #3, line #1465
# File #3, line #1466
# File #3, line #1467
# File #3, line #1468
# File #3, line #1469
# File #3, line #1470
# File #3, line #1471
# File #3, line #1472
# File #3, line #1473
# File #3, line #1474
# File #3, line #1475
# File #3, line #1476
# File #3, line #1477
# File #3, line #1478
# File #3, line #1479
# File #3, line #1480
# File #3, line #1481
# File #3, line #1482
# File #3, line #1483
# File #3, line #1484
# File #3, line #1485
# File #3, line #1486
# File #3, line #1487
# File #3, line #1488
# File #3, line #1489
# File #3, line #1490
# File #3, line #1491
# File #3, line #1492
# File #3, line #1493
# File #3, line #1494
# File #3, line #1495
# File #3, line #1496
# File #3, line #1497
# File #3, line #1498
# File #3, line #1499
# File #3, line #1500
# File #3, line #1501
# File #3, line #1502
# File #3, line #1503
# File #3, line #1504
# File #3, line #1505
# File #3, line #1506
# File #3, line #1507
# File #3, line #1508
# File #3, line #1509
# File #3, line #1510
# File #3, line #1511
# File #3, line #1512
# File #3, line #1513
# File #3, line #1514
# File #3, line #1515
# File #3, line #1516
# File #3, line #1517
# File #3, line #1518
# File #3, line #1519
# File #3, line #1520
# File #3, line #1521
# File #3, line #1522
# File #3, line #1523
# File #3, line #1524
# File #3, line #1525
# File #3, line #1526
# File #3, line #1527
# File #3, line #1528
# File #3, line #1529
# File #3, line #1530
# File #3, line #1531
# File #3, line #1532
# File #3, line #1533
# File #3, line #1534
# File #3, line #1535
# File #3, line #1536
# File #3, line #1537
# File #3, line #1538
# File #3, line #1539
# File #3, line #1540
# File #3, line #1541
# File #3, line #1542
# File #3, line #1543
# File #3, line #1544
# File #3, line #1545
# File #3, line #1546
# File #3, line #1547
# File #3, line #1548
# File #3, line #1549
# File #3, line #1550
# File #3, line #1551
# File #3, line #1552
# File #3, line #1553
# File #3, line #1554
# File #3, line #1555
# File #3, line #1556
# File #3, line #1557
# File #3, line #1558
# File #3, line #1559
# File #3, line #1560
# File #3, line #1561
# File #3, line #1562
# File #3, line #1563
# File #3, line #1564
# File #3, line #1565
# File #3, line #1566
# File #3, line #1567
# File #3, line #1568
# File #3, line #1569
# File #3, line #1570
# File #3, line #1571
# File #3, line #1572
# File #3, line #1573
# File #3, line #1574
# File #3, line #1575
# File #3, line #1576
# File #3, line #1577
# File #3, line #1578
# File #3, line #1579
# File #3, line #1580
# File #3, line #1581
# File #3, line #1582
# File #3, line #1583
# File #3, line #1584
# File #3, line #1585
# File #3, line #1586
# File #3, line #1587
# File #3, line #1588
# File #3, line #1589
# File #3, line #1590
# File #3, line #1591
# File #3, line #1592
# File #3, line #1593
# File #3, line #1594
# File #3, line #1595
# File #3, line #1596
# File #3, line #1597
# File #3, line #1598
# File #3, line #1599
# File #3, line #1600
# File #3, line #1601
# File #3, line #1602
# File #3, line #1603
# File #3, line #1604
# File #3, line #1605
# File #3, line #1606
# File #3, line #1607
# File #3, line #1608
# File #3, line #1609
# File #3, line #1610
# File #3, line #1611
# File #3, line #1612
# File #3, line #1613
# File #3, line #1614
# File #3, line #1615
# File #3, line #1616
# File #3, line #1617
# File #3, line #1618
# File #3, line #1619
# File #3, line #1620
# File #3, line #1621
# File #3, line #1622
# File #3, line #1623
# File #3, line #1624
# File #3, line #1625
# File #3, line #1626
# File #3, line #1627
# File #3, line #1628
# File #3, line #1629
# File #3, line #1630
# File #3, line #1631
# File #3, line #1632
# File #3, line #1633
# File #3, line #1634
# File #3, line #1635
# File #3, line #1636
# File #3, line #1637
# File #3, line #1638
# File #3, line #1639
# File #3, line #1640
# File #3, line #1641
# File #3, line #1642
# File #3, line #1643
# File #3, line #1644
# File #3, line #1645
# File #3, line #1646
# File #3, line #1647
# File #3, line #1648
# File #3, line #1649
# File #3, line #1650
# File #3, line #1651
# File #3, line #1652
# File #3, line #1653
# File #3, line #1654
# File #3, line #1655
# File #3, line #1656
# File #3, line #1657
# File #3, line #1658
# File #3, line #1659
# File #3, line #1660
# File #3, line #1661
# File #3, line #1662
# File #3, line #1663
# File #3, line #1664
# File #3, line #1665
# File #3, line #1666
# File #3, line #1667
# File #3, line #1668
# File #3, line #1669
# File #3, line #1670
# File #3, line #1671
# File #3, line #1672
# File #3, line #1673
# File #3, line #1674
# File #3, line #1675
# File #3, line #1676
# File #3, line #1677
# File #3, line #1678
# File #3, line #1679
# File #3, line #1680
# File #3, line #1681
# File #3, line #1682
# File #3, line #1683
# File #3, line #1684
# File #3, line #1685
# File #3, line #1686
# File #3, line #1687
# File #3, line #1688
# File #3, line #1689
# File #3, line #1690
# File #3, line #1691
# File #3, line #1692
# File #3, line #1693
# File #3, line #1694
# File #3, line #1695
# File #3, line #1696
# File #3, line #1697
# File #3, line #1698
# File #3, line #1699
# File #3, line #1700
# File #3, line #1701
# File #3, line #1702
# File #3, line #1703
# File #3, line #1704
# File #3, line #1705
# File #3, line #1706
# File #3, line #1707
# File #3, line #1708
# File #3, line #1709
# File #3, line #1710
# File #3, line #1711
# File #3, line #1712
# File #3, line #1713
# File #3, line #1714
# File #3, line #1715
# File #3, line #1716
# File #3, line #1717
# File #3, line #1718
# File #3, line #1719
# File #3, line #1720
# File #3, line #1721
# File #3, line #1722
# File #3, line #1723
# File #3, line #1724
# File #3, line #1725
# File #3, line #1726
# File #3, line #1727
# File #3, line #1728
# File #3, line #1729
# File #3, line #1730
# File #3, line #1731
# File #3, line #1732
# File #3, line #1733
# File #3, line #1734
# File #3, line #1735
# File #3, line #1736
# File #3, line #1737
# File #3, line #1738
# File #3, line #1739
# File #3, line #1740
# File #3, line #1741
# File #3, line #1742
# File #3, line #1743
# File #3, line #1744
# File #3, line #1745
# File #3, line #1746
# File #3, line #1747
# File #3, line #1748
# File #3, line #1749
# File #3, line #1750
# File #3, line #1751
# File #3, line #1752
# File #3, line #1753
# File #3, line #1754
# File #3, line #1755
# File #3, line #1756
# File #3, line #1757
# File #3, line #1758
# File #3, line #1759
# File #3, line #1760
# File #3, line #1761
# File #3, line #1762
# File #3, line #1763
# File #3, line #1764
# File #3, line #1765
# File #3, line #1766
# File #3, line #1767
# File #3, line #1768
# File #3, line #1769
# File #3, line #1770
# File #3, line #1771
# File #3, line #1772
# File #3, line #1773
# File #3, line #1774
# File #3, line #1775
# File #3, line #1776
# File #3, line #1777
# File #3, line #1778
# File #3, line #1779
# File #3, line #1780
# File #3, line #1781
# File #3, line #1782
# File #3, line #1783
# File #3, line #1784
# File #3, line #1785
# File #3, line #1786
# File #3, line #1787
# File #3, line #1788
# File #3, line #1789
# File #3, line #1790
# File #3, line #1791
# File #3, line #1792
# File #3, line #1793
# File #3, line #1794
# File #3, line #1795
# File #3, line #1796
# File #3, line #1797
# File #3, line #1798
# File #3, line #1799
# File #3, line #1800
# File #3, line #1801
# File #3, line #1802
# File #3, line #1803
# File #3, line #1804
# File #3, line #1805
# File #3, line #1806
# File #3, line #1807
# File #3, line #1808
# File #3, line #1809
# File #3, line #1810
# File #3, line #1811
# File #3, line #1812
# File #3, line #1813
# File #3, line #1814
# File #3, line #1815
# File #3, line #1816
# File #3, line #1817
# File #3, line #1818
# File #3, line #1819
# File #3, line #1820
# File #3, line #1821
# File #3, line #1822
# File #3, line #1823
# File #3, line #1824
# File #3, line #1825
# File #3, line #1826
# File #3, line #1827
# File #3, line #1828
# File #3, line #1829
# File #3, line #1830
# File #3, line #1831
# File #3, line #1832
# File #3, line #1833
# File #3, line #1834
# File #3, line #1835
# File #3, line #1836
# File #3, line #1837
# File #3, line #1838
# File #3, line #1839
# File #3, line #1840
# File #3, line #1841
# File #3, line #1842
# File #3, line #1843
# File #3, line #1844
# File #3, line #1845
# File #3, line #1846
# File #3, line #1847
# File #3, line #1848
# File #3, line #1849
# File #3, line #1850
# File #3, line #1851
# File #3, line #1852
# File #3, line #1853
# File #3, line #1854
# File #3, line #1855
# File #3, line #1856
# File #3, line #1857
# File #3, line #1858
# File #3, line #1859
# File #3, line #1860
# File #3, line #1861
# File #3, line #1862
# File #3, line #1863
# File #3, line #1864
# File #3, line #1865
# File #3, line #1866
# File #3, line #1867
# File #3, line #1868
# File #3, line #1869
# File #3, line #1870
# File #3, line #1871
# File #3, line #1872
# File #3, line #1873
# File #3, line #1874
# File #3, line #1875
# File #3, line #1876
# File #3, line #1877
# File #3, line #1878
# File #3, line #1879
# File #3, line #1880
# File #3, line #1881
# File #3, line #1882
# File #3, line #1883
# File #3, line #1884
# File #3, line #1885
# File #3, line #1886
# File #3, line #1887
# File #3, line #1888
# File #3, line #1889
# File #3, line #1890
# File #3, line #1891
# File #3, line #1892
# File #3, line #1893
# File #3, line #1894
# File #3, line #1895
# File #3, line #1896
# File #3, line #1897
# File #3, line #1898
# File #3, line #1899
# File #3, line #1900
# File #3, line #1901
# File #3, line #1902
# File #3, line #1903
# File #3, line #1904
# File #3, line #1905
# File #3, line #1906
# File #3, line #1907
# File #3, line #1908
# File #3, line #1909
# File #3, line #1910
# File #3, line #1911
# File #3, line #1912
# File #3, line #1913
# File #3, line #1914
# File #3, line #1915
# File #3, line #1916
# File #3, line #1917
# File #3, line #1918
# File #3, line #1919
# File #3, line #1920
# File #3, line #1921
# File #3, line #1922
# File #3, line #1923
# File #3, line #1924
# File #3, line #1925
# File #3, line #1926
# File #3, line #1927
# File #3, line #1928
# File #3, line #1929
# File #3, line #1930
# File #3, line #1931
# File #3, line #1932
# File #3, line #1933
# File #3, line #1934
# File #3, line #1935
# File #3, line #1936
# File #3, line #1937
# File #3, line #1938
# File #3, line #1939
# File #3, line #1940
# File #3, line #1941
# File #3, line #1942
# File #3, line #1943
# File #3, line #1944
# File #3, line #1945
# File #3, line #1946
# File #3, line #1947
# File #3, line #1948
# File #3, line #1949
# File #3, line #1950
# File #3, line #1951
# File #3, line #1952
# File #3, line #1953
# File #3, line #1954
# File #3, line #1955
# File #3, line #1956
# File #3, line #1957
# File #3, line #1958
# File #3, line #1959
# File #3, line #1960
# File #3, line #1961
# File #3, line #1962
# File #3, line #1963
# File #3, line #1964
# File #3, line #1965
# File #3, line #1966
# File #3, line #1967
# File #3, line #1968
# File #3, line #1969
# File #3, line #1970
# File #3, line #1971
# File #3, line #1972
# File #3, line #1973
# File #3, line #1974
# File #3, line #1975
# File #3, line #1976
# File #3, line #1977
# File #3, line #1978
# File #3, line #1979
# File #3, line #1980
# File #3, line #1981
# File #3, line #1982
# File #3, line #1983
# File #3, line #1984
# File #3, line #1985
# File #3, line #1986
# File #3, line #1987
# File #3, line #1988
# File #3, line #1989
# File #3, line #1990
# File #3, line #1991
# File #3, line #1992
# File #3, line #1993
# File #3, line #1994
# File #3, line #1995
# File #3, line #1996
# File #3, line #1997
# File #3, line #1998
# File #3, line #1999
# File #3, line #2000
# File #3, line #2001
# File #3, line #2002
# File #3, line #2003
# File #3, line #2004
# File #3, line #2005
# File #3, line #2006
# File #3, line #2007
# File #3, line #2008
# File #3, line #2009
# File #3, line #2010
# File #3, line #2011
# File #3, line #2012
# File #3, line #2013
# File #3, line #2014
# File #3, line #2015
# File #3, line #2016
# File #3, line #2017
# File #3, line #2018
# File #3, line #2019
# File #3, line #2020
# File #3, line #2021
# File #3, line #2022
# File #3, line #2023
# File #3, line #2024
# File #3, line #2025
# File #3, line #2026
# File #3, line #2027
# File #3, line #2028
# File #3, line #2029
# File #3, line #2030
# File #3, line #2031
# File #3, line #2032
# File #3, line #2033
# File #3, line #2034
# File #3, line #2035
# File #3, line #2036
# File #3, line #2037
# File #3, line #2038
# File #3, line #2039
# File #3, line #2040
# File #3, line #2041
# File #3, line #2042
# File #3, line #2043
# File #3, line #2044
# File #3, line #2045
# File #3, line #2046
# File #3, line #2047
# File #3, line #2048
# File #3, line #2049
# File #3, line #2050
# File #3, line #2051
# File #3, line #2052
# File #3, line #2053
# File #3, line #2054
# File #3, line #2055
# File #3, line #2056
# File #3, line #2057
# File #3, line #2058
# File #3, line #2059
# File #3, line #2060
# File #3, line #2061
# File #3, line #2062
# File #3, line #2063
# File #3, line #2064
# File #3, line #2065
# File #3, line #2066
# File #3, line #2067
# File #3, line #2068
# File #3, line #2069
# File #3, line #2070
# File #3, line #2071
# File #3, line #2072
# File #3, line #2073
# File #3, line #2074
# File #3, line #2075
# File #3, line #2076
# File #3, line #2077
# File #3, line #2078
# File #3, line #2079
# File #3, line #2080
# File #3, line #2081
# File #3, line #2082
# File #3, line #2083
# File #3, line #2084
# File #3, line #2085
# File #3, line #2086
# File #3, line #2087
# File #3, line #2088
# File #3, line #2089
# File #3, line #2090
# File #3, line #2091
# File #3, line #2092
# File #3, line #2093
# File #3, line #2094
# File #3, line #2095
# File #3, line #2096
# File #3, line #2097
# File #3, line #2098
# File #3, line #2099
# File #3, line #2100
# File #3, line #2101
# File #3, line #2102
# File #3, line #2103
# File #3, line #2104
# File #3, line #2105
# File #3, line #2106
# File #3, line #2107
# File #3, line #2108
# File #3, line #2109
# File #3, line #2110
# File #3, line #2111
# File #3, line #2112
# File #3, line #2113
# File #3, line #2114
# File #3, line #2115
# File #3, line #2116
# File #3, line #2117
# File #3, line #2118
# File #3, line #2119
# File #3, line #2120
# File #3, line #2121
# File #3, line #2122
# File #3, line #2123
# File #3, line #2124
# File #3, line #2125
# File #3, line #2126
# File #3, line #2127
# File #3, line #2128
# File #3, line #2129
# File #3, line #2130
# File #3, line #2131
# File #3, line #2132
# File #3, line #2133
# File #3, line #2134
# File #3, line #2135
# File #3, line #2136
# File #3, line #2137
# File #3, line #2138
# File #3, line #2139
# File #3, line #2140
# File #3, line #2141
# File #3, line #2142
# File #3, line #2143
# File #3, line #2144
# File #3, line #2145
# File #3, line #2146
# File #3, line #2147
# File #3, line #2148
# File #3, line #2149
# File #3, line #2150
# File #3, line #2151
# File #3, line #2152
# File #3, line #2153
# File #3, line #2154
# File #3, line #2155
# File #3, line #2156
# File #3, line #2157
# File #3, line #2158
# File #3, line #2159
# File #3, line #2160
# File #3, line #2161
# File #3, line #2162
# File #3, line #2163
# File #3, line #2164
# File #3, line #2165
# File #3, line #2166
# File #3, line #2167
# File #3, line #2168
# File #3, line #2169
# File #3, line #2170
# File #3, line #2171
# File #3, line #2172
# File #3, line #2173
# File #3, line #2174
# File #3, line #2175
# File #3, line #2176
# File #3, line #2177
# File #3, line #2178
# File #3, line #2179
# File #3, line #2180
# File #3, line #2181
# File #3, line #2182
# File #3, line #2183
# File #3, line #2184
# File #3, line #2185
# File #3, line #2186
# File #3, line #2187
# File #3, line #2188
# File #3, line #2189
# File #3, line #2190
# File #3, line #2191
# File #3, line #2192
# File #3, line #2193
# File #3, line #2194
# File #3, line #2195
# File #3, line #2196
# File #3, line #2197
# File #3, line #2198
# File #3, line #2199
# File #3, line #2200
# File #3, line #2201
# File #3, line #2202
# File #3, line #2203
# File #3, line #2204
# File #3, line #2205
# File #3, line #2206
# File #3, line #2207
# File #3, line #2208
# File #3, line #2209
# File #3, line #2210
# File #3, line #2211
# File #3, line #2212
# File #3, line #2213
# File #3, line #2214
# File #3, line #2215
# File #3, line #2216
# File #3, line #2217
# File #3, line #2218
# File #3, line #2219
# File #3, line #2220
# File #3, line #2221
# File #3, line #2222
# File #3, line #2223
# File #3, line #2224
# File #3, line #2225
# File #3, line #2226
# File #3, line #2227
# File #3, line #2228
# File #3, line #2229
# File #3, line #2230
# File #3, line #2231
# File #3, line #2232
# File #3, line #2233
# File #3, line #2234
# File #3, line #2235
# File #3, line #2236
# File #3, line #2237
# File #3, line #2238
# File #3, line #2239
# File #3, line #2240
# File #3, line #2241
# File #3, line #2242
# File #3, line #2243
# File #3, line #2244
# File #3, line #2245
# File #3, line #2246
# File #3, line #2247
# File #3, line #2248
# File #3, line #2249
# File #3, line #2250
# File #3, line #2251
# File #3, line #2252
# File #3, line #2253
# File #3, line #2254
# File #3, line #2255
# File #3, line #2256
# File #3, line #2257
# File #3, line #2258
# File #3, line #2259
# File #3, line #2260
# File #3, line #2261
# File #3, line #2262
# File #3, line #2263
# File #3, line #2264
# File #3, line #2265
# File #3, line #2266
# File #3, line #2267
# File #3, line #2268
# File #3, line #2269
# File #3, line #2270
# File #3, line #2271
# File #3, line #2272
# File #3, line #2273
# File #3, line #2274
# File #3, line #2275
# File #3, line #2276
# File #3, line #2277
# File #3, line #2278
# File #3, line #2279
# File #3, line #2280
# File #3, line #2281
# File #3, line #2282
# File #3, line #2283
# File #3, line #2284
# File #3, line #2285
# File #3, line #2286
# File #3, line #2287
# File #3, line #2288
# File #3, line #2289
# File #3, line #2290
# File #3, line #2291
# File #3, line #2292
# File #3, line #2293
# File #3, line #2294
# File #3, line #2295
# File #3, line #2296
# File #3, line #2297
# File #3, line #2298
# File #3, line #2299
# File #3, line #2300
# File #3, line #2301
# File #3, line #2302
# File #3, line #2303
# File #3, line #2304
# File #3, line #2305
# File #3, line #2306
# File #3, line #2307
# File #3, line #2308
# File #3, line #2309
# File #3, line #2310
# File #3, line #2311
# File #3, line #2312
# File #3, line #2313
# File #3, line #2314
# File #3, line #2315
# File #3, line #2316
# File #3, line #2317
# File #3, line #2318
# File #3, line #2319
# File #3, line #2320
# File #3, line #2321
# File #3, line #2322
# File #3, line #2323
# File #3, line #2324
# File #3, line #2325
# File #3, line #2326
# File #3, line #2327
# File #3, line #2328
# File #3, line #2329
# File #3, line #2330
# File #3, line #2331
# File #3, line #2332
# File #3, line #2333
# File #3, line #2334
# File #3, line #2335
# File #3, line #2336
# File #3, line #2337
# File #3, line #2338
# File #3, line #2339
# File #3, line #2340
# File #3, line #2341
# File #3, line #2342
# File #3, line #2343
# File #3, line #2344
# File #3, line #2345
# File #3, line #2346
# File #3, line #2347
# File #3, line #2348
# File #3, line #2349
# File #3, line #2350
# File #3, line #2351
# File #3, line #2352
# File #3, line #2353
# File #3, line #2354
# File #3, line #2355
# File #3, line #2356
# File #3, line #2357
# File #3, line #2358
# File #3, line #2359
# File #3, line #2360
# File #3, line #2361
# File #3, line #2362
# File #3, line #2363
# File #3, line #2364
# File #3, line #2365
# File #3, line #2366
# File #3, line #2367
# File #3, line #2368
# File #3, line #2369
# File #3, line #2370
# File #3, line #2371
# File #3, line #2372
# File #3, line #2373
# File #3, line #2374
# File #3, line #2375
# File #3, line #2376
# File #3, line #2377
# File #3, line #2378
# File #3, line #2379
# File #3, line #2380
# File #3, line #2381
# File #3, line #2382
# File #3, line #2383
# File #3, line #2384
# File #3, line #2385
# File #3, line #2386
# File #3, line #2387
# File #3, line #2388
# File #3, line #2389
# File #3, line #2390
# File #3, line #2391
# File #3, line #2392
# File #3, line #2393
# File #3, line #2394
# File #3, line #2395
# File #3, line #2396
# File #3, line #2397
# File #3, line #2398
# File #3, line #2399
# File #3, line #2400
# File #3, line #2401
# File #3, line #2402
# File #3, line #2403
# File #3, line #2404
# File #3, line #2405
# File #3, line #2406
# File #3, line #2407
# File #3, line #2408
# File #3, line #2409
# File #3, line #2410
# File #3, line #2411
# File #3, line #2412
# File #3, line #2413
# File #3, line #2414
# File #3, line #2415
# File #3, line #2416
# File #3, line #2417
# File #3, line #2418
# File #3, line #2419
# File #3, line #2420
# File #3, line #2421
# File #3, line #2422
# File #3, line #2423
# File #3, line #2424
# File #3, line #2425
# File #3, line #2426
# File #3, line #2427
# File #3, line #2428
# File #3, line #2429
# File #3, line #2430
# File #3, line #2431
# File #3, line #2432
# File #3, line #2433
# File #3, line #2434
# File #3, line #2435
# File #3, line #2436
# File #3, line #2437
# File #3, line #2438
# File #3, line #2439
# File #3, line #2440
# ...
# File #68, line #24357
# File #68, line #24358
# File #68, line #24359
# File #68, line #24360
# File #68, line #24361
# File #68, line #24362
# File #68, line #24363
# File #68, line #24364
# File #68, line #24365
# File #68, line #24366
# File #68, line #24367
# File #68, line #24368
# File #68, line #24369
# File #68, line #24370
# File #68, line #24371
# File #68, line #24372
# File #68, line #24373
# File #68, line #24374
# File #68, line #24375
# File #68, line #24376
# File #68, line #24377
# File #68, line #24378
# File #68, line #24379
# File #68, line #24380
# File #68, line #24381
# File #68, line #24382
# File #68, line #24383
# File #68, line #24384
# File #68, line #24385
# File #68, line #24386
# File #68, line #24387
# File #68, line #24388
# File #68, line #24389
# File #68, line #24390
# File #68, line #24391
# File #68, line #24392
# File #68, line #24393
# File #68, line #24394
# File #68, line #24395
# File #68, line #24396
# File #68, line #24397
# File #68, line #24398
# File #68, line #24399
# File #68, line #24400
# File #68, line #24401
# File #68, line #24402
# File #68, line #24403
# File #68, line #24404
# File #68, line #24405
# File #68, line #24406
# File #68, line #24407
# File #68, line #24408
# File #68, line #24409
# File #68, line #24410
# File #68, line #24411
# File #68, line #24412
# File #68, line #24413
# File #68, line #24414
# File #68, line #24415
# File #68, line #24416
# File #68, line #24417
# File #68, line #24418
# File #68, line #24419
# File #68, line #24420
# File #68, line #24421
# File #68, line #24422
# File #68, line #24423
# File #68, line #24424
# File #68, line #24425
# File #68, line #24426
# File #68, line #24427
# File #68, line #24428
# File #68, line #24429
# File #68, line #24430
# File #68, line #24431
# File #68, line #24432
# File #68, line #24433
# File #68, line #24434
# File #68, line #24435
# File #68, line #24436
# File #68, line #24437
# File #68, line #24438
# File #68, line #24439
# File #68, line #24440
# File #68, line #24441
# File #68, line #24442
# File #68, line #24443
# File #68, line #24444
# File #68, line #24445
# File #68, line #24446
# File #68, line #24447
# File #68, line #24448
# File #68, line #24449
# File #68, line #24450
# File #68, line #24451
# File #68, line #24452
# File #68, line #24453
# File #68, line #24454
# File #68, line #24455
# File #68, line #24456
# File #68, line #24457
# File #68, line #24458
# File #68, line #24459
# File #68, line #24460
# File #68, line #24461
# File #68, line #24462
# File #68, line #24463
# File #68, line #24464
# File #68, line #24465
# File #68, line #24466
# File #68, line #24467
# File #68, line #24468
# File #68, line #24469
# File #68, line #24470
# File #68, line #24471
# File #68, line #24472
# File #68, line #24473
# File #68, line #24474
# File #68, line #24475
# File #68, line #24476
# File #68, line #24477
# File #68, line #24478
# File #68, line #24479
# File #68, line #24480
# File #68, line #24481
# File #68, line #24482
# File #68, line #24483
# File #68, line #24484
# File #68, line #24485
# File #68, line #24486
# File #68, line #24487
# File #68, line #24488
# File #68, line #24489
# File #68, line #24490
# File #68, line #24491
# File #68, line #24492
# File #68, line #24493
# File #68, line #24494
# File #68, line #24495
# File #68, line #24496
# File #68, line #24497
# File #68, line #24498
# File #68, line #24499
# File #68, line #24500
# File #68, line #24501
# File #68, line #24502
# File #68, line #24503
# File #68, line #24504
# File #68, line #24505
# File #68, line #24506
# File #68, line #24507
# File #68, line #24508
# File #68, line #24509
# File #68, line #24510
# File #68, line #24511
# File #68, line #24512
# File #68, line #24513
# File #68, line #24514
# File #68, line #24515
# File #68, line #24516
# File #68, line #24517
# File #68, line #24518
# File #68, line #24519
# File #68, line #24520
# File #68, line #24521
# File #68, line #24522
# File #68, line #24523
# File #68, line #24524
# File #68, line #24525
# File #68, line #24526
# File #68, line #24527
# File #68, line #24528
# File #68, line #24529
# File #68, line #24530
# File #68, line #24531
# File #68, line #24532
# File #68, line #24533
# File #68, line #24534
# File #68, line #24535
# File #68, line #24536
# File #68, line #24537
# File #68, line #24538
# File #68, line #24539
# File #68, line #24540
# File #68, line #24541
# File #68, line #24542
# File #68, line #24543
# File #68, line #24544
# File #68, line #24545
# File #68, line #24546
# File #68, line #24547
# File #68, line #24548
# File #68, line #24549
# File #68, line #24550
# File #68, line #24551
# File #68, line #24552
# File #68, line #24553
# File #68, line #24554
# File #68, line #24555
# File #68, line #24556
# File #68, line #24557
# File #68, line #24558
# File #68, line #24559
# File #68, line #24560
# File #68, line #24561
# File #68, line #24562
# File #68, line #24563
# File #68, line #24564
# File #68, line #24565
# File #68, line #24566
# File #68, line #24567
# File #68, line #24568
# File #68, line #24569
# File #68, line #24570
# File #68, line #24571
# File #68, line #24572
# File #68, line #24573
# File #68, line #24574
# File #68, line #24575
# File #68, line #24576
# File #68, line #24577
# File #68, line #24578
# File #68, line #24579
# File #68, line #24580
# File #68, line #24581
# File #68, line #24582
# File #68, line #24583
# File #68, line #24584
# File #68, line #24585
# File #68, line #24586
# File #68, line #24587
# File #68, line #24588
# File #68, line #24589
# File #68, line #24590
# File #68, line #24591
# File #68, line #24592
# File #68, line #24593
# File #68, line #24594
# File #68, line #24595
# File #68, line #24596
# File #68, line #24597
# File #68, line #24598
# File #68, line #24599
# File #68, line #24600
# File #68, line #24601
# File #68, line #24602
# File #68, line #24603
# File #68, line #24604
# File #68, line #24605
# File #68, line #24606
# File #68, line #24607
# File #68, line #24608
# File #68, line #24609
# File #68, line #24610
# File #68, line #24611
# File #68, line #24612
# File #68, line #24613
# File #68, line #24614
# File #68, line #24615
# File #68, line #24616
# File #68, line #24617
# File #68, line #24618
# File #68, line #24619
# File #68, line #24620
# File #68, line #24621
# File #68, line #24622
# File #68, line #24623
# File #68, line #24624
# File #68, line #24625
# File #68, line #24626
# File #68, line #24627
# File #68, line #24628
# File #68, line #24629
# File #68, line #24630
# File #68, line #24631
# File #68, line #24632
# File #68, line #24633
# File #68, line #24634
# File #68, line #24635
# File #68, line #24636
# File #68, line #24637
# File #68, line #24638
# File #68, line #24639
# File #68, line #24640
# File #68, line #24641
# File #68, line #24642
# File #68, line #24643
# File #68, line #24644
# File #68, line #24645
# File #68, line #24646
# File #68, line #24647
# File #68, line #24648
# File #68, line #24649
# File #68, line #24650
# File #68, line #24651
# File #68, line #24652
# File #68, line #24653
# File #68, line #24654
# File #68, line #24655
# File #68, line #24656
# File #68, line #24657
# File #68, line #24658
# File #68, line #24659
# File #68, line #24660
# File #68, line #24661
# File #68, line #24662
# File #68, line #24663
# File #68, line #24664
# File #68, line #24665
# File #68, line #24666
# File #68, line #24667
# File #68, line #24668
# File #68, line #24669
# File #68, line #24670
# File #68, line #24671
# File #68, line #24672
# File #68, line #24673
# File #68, line #24674
# File #68, line #24675
# File #68, line #24676
# File #68, line #24677
# File #68, line #24678
# File #68, line #24679
# File #68, line #24680
# File #68, line #24681
# File #68, line #24682
# File #68, line #24683
# File #68, line #24684
# File #68, line #24685
# File #68, line #24686
# File #68, line #24687
# File #68, line #24688
# File #68, line #24689
# File #68, line #24690
# File #68, line #24691
# File #68, line #24692
# File #68, line #24693
# File #68, line #24694
# File #68, line #24695
# File #68, line #24696
# File #68, line #24697
# File #68, line #24698
# File #68, line #24699
# File #68, line #24700
# File #68, line #24701
# File #68, line #24702
# File #68, line #24703
# File #68, line #24704
# File #68, line #24705
# File #68, line #24706
# File #68, line #24707
# File #68, line #24708
# File #68, line #24709
# File #68, line #24710
# File #68, line #24711
# File #68, line #24712
# File #68, line #24713
# File #68, line #24714
# File #68, line #24715
# File #68, line #24716
# File #68, line #24717
# File #68, line #24718
# File #68, line #24719
# File #68, line #24720
# File #68, line #24721
# File #68, line #24722
# File #68, line #24723
# File #68, line #24724
# File #68, line #24725
# File #68, line #24726
# File #68, line #24727
# File #68, line #24728
# File #68, line #24729
# File #68, line #24730
# File #68, line #24731
# File #68, line #24732
# File #68, line #24733
# File #68, line #24734
# File #68, line #24735
# File #68, line #24736
# File #68, line #24737
# File #68, line #24738
# File #68, line #24739
# File #68, line #24740
# File #68, line #24741
# File #68, line #24742
# File #68, line #24743
# File #68, line #24744
# File #68, line #24745
# File #68, line #24746
# File #68, line #24747
# File #68, line #24748
# File #68, line #24749
# File #68, line #24750
# File #68, line #24751
# File #68, line #24752
# File #68, line #24753
# File #68, line #24754
# File #68, line #24755
# File #68, line #24756
# File #68, line #24757
# File #68, line #24758
# File #68, line #24759
# File #68, line #24760
# File #68, line #24761
# File #68, line #24762
# File #68, line #24763
# File #68, line #24764
# File #68, line #24765
# File #68, line #24766
# File #68, line #24767
# File #68, line #24768
# File #68, line #24769
# File #68, line #24770
# File #68, line #24771
# File #68, line #24772
# File #68, line #24773
# File #68, line #24774
# File #68, line #24775
# File #68, line #24776
# File #68, line #24777
# File #68, line #24778
# File #68, line #24779
# File #68, line #24780
# File #68, line #24781
# File #68, line #24782
# File #68, line #24783
# File #68, line #24784
# File #68, line #24785
# File #68, line #24786
# File #68, line #24787
# File #68, line #24788
# File #68, line #24789
# File #68, line #24790
# File #68, line #24791
# File #68, line #24792
# File #68, line #24793
# File #68, line #24794
# File #68, line #24795
# File #68, line #24796
# File #68, line #24797
# File #68, line #24798
# File #68, line #24799
# File #68, line #24800
# File #68, line #24801
# File #68, line #24802
# File #68, line #24803
# File #68, line #24804
# File #68, line #24805
# File #68, line #24806
# File #68, line #24807
# File #68, line #24808
# File #68, line #24809
# File #68, line #24810
# File #68, line #24811
# File #68, line #24812
# File #68, line #24813
# File #68, line #24814
# File #68, line #24815
# File #68, line #24816
# File #68, line #24817
# File #68, line #24818
# File #68, line #24819
# File #68, line #24820
# File #68, line #24821
# File #68, line #24822
# File #68, line #24823
# File #68, line #24824
# File #68, line #24825
# File #68, line #24826
# File #68, line #24827
# File #68, line #24828
# File #68, line #24829
# File #68, line #24830
# File #68, line #24831
# File #68, line #24832
# File #68, line #24833
# File #68, line #24834
# File #68, line #24835
# File #68, line #24836
# File #68, line #24837
# File #68, line #24838
# File #68, line #24839
# File #68, line #24840
# File #68, line #24841
# File #68, line #24842
# File #68, line #24843
# File #68, line #24844
# File #68, line #24845
# File #68, line #24846
# File #68, line #24847
# File #68, line #24848
# File #68, line #24849
# File #68, line #24850
# File #68, line #24851
# File #68, line #24852
# File #68, line #24853
# File #68, line #24854
# File #68, line #24855
# File #68, line #24856
# File #68, line #24857
# File #68, line #24858
# File #68, line #24859
# File #68, line #24860
# File #68, line #24861
# File #68, line #24862
# File #68, line #24863
# File #68, line #24864
# File #68, line #24865
# File #68, line #24866
# File #68, line #24867
# File #68, line #24868
# File #68, line #24869
# File #68, line #24870
# File #68, line #24871
# File #68, line #24872
# File #68, line #24873
# File #68, line #24874
# File #68, line #24875
# File #68, line #24876
# File #68, line #24877
# File #68, line #24878
# File #68, line #24879
# File #68, line #24880
# File #68, line #24881
# File #68, line #24882
# File #68, line #24883
# File #68, line #24884
# File #68, line #24885
# File #68, line #24886
# File #68, line #24887
# File #68, line #24888
# File #68, line #24889
# File #68, line #24890
# File #68, line #24891
# File #68, line #24892
# File #68, line #24893
# File #68, line #24894
# File #68, line #24895
# File #68, line #24896
# File #68, line #24897
# File #68, line #24898
# File #68, line #24899
# File #68, line #24900
# File #68, line #24901
# File #68, line #24902
# File #68, line #24903
# File #68, line #24904
# File #68, line #24905
# File #68, line #24906
# File #68, line #24907
# File #68, line #24908
# File #68, line #24909
# File #68, line #24910
# File #68, line #24911
# File #68, line #24912
# File #68, line #24913
# File #68, line #24914
# File #68, line #24915
# File #68, line #24916
# File #68, line #24917
# File #68, line #24918
# File #68, line #24919
# File #68, line #24920
# File #68, line #24921
# File #68, line #24922
# File #68, line #24923
# File #68, line #24924
# File #68, line #24925
# File #68, line #24926
# File #68, line #24927
# File #68, line #24928
# File #68, line #24929
# File #68, line #24930
# File #68, line #24931
# File #68, line #24932
# File #68, line #24933
# File #68, line #24934
# File #68, line #24935
# File #68, line #24936
# File #68, line #24937
# File #68, line #24938
# File #68, line #24939
# File #68, line #24940
# File #68, line #24941
# File #68, line #24942
# File #68, line #24943
# File #68, line #24944
# File #68, line #24945
# File #68, line #24946
# File #68, line #24947
# File #68, line #24948
# File #68, line #24949
# File #68, line #24950
# File #68, line #24951
# File #68, line #24952
# File #68, line #24953
# File #68, line #24954
# File #68, line #24955
# File #68, line #24956
# File #68, line #24957
# File #68, line #24958
# File #68, line #24959
# File #68, line #24960
# File #68, line #24961
# File #68, line #24962
# File #68, line #24963
# File #68, line #24964
# File #68, line #24965
# File #68, line #24966
# File #68, line #24967
# File #68, line #24968
# File #68, line #24969
# File #68, line #24970
# File #68, line #24971
# File #68, line #24972
# File #68, line #24973
# File #68, line #24974
# File #68, line #24975
# File #68, line #24976
# File #68, line #24977
# File #68, line #24978
# File #68, line #24979
# File #68, line #24980
# File #68, line #24981
# File #68, line #24982
# File #68, line #24983
# File #68, line #24984
# File #68, line #24985
# File #68, line #24986
# File #68, line #24987
# File #68, line #24988
# File #68, line #24989
# File #68, line #24990
# File #68, line #24991
# File #68, line #24992
# File #68, line #24993
# File #68, line #24994
# File #68, line #24995
# File #68, line #24996
# File #68, line #24997
# File #68, line #24998
# File #68, line #24999
# File #68, line #25000
# File #68, line #25001
# File #68, line #25002
# File #68, line #25003
# File #68, line #25004
# File #68, line #25005
# File #68, line #25006
# File #68, line #25007
# File #68, line #25008
# File #68, line #25009
# File #68, line #25010
# File #68, line #25011
# File #68, line #25012
# File #68, line #25013
# File #68, line #25014
# File #68, line #25015
# File #68, line #25016
# File #68, line #25017
# File #68, line #25018
# File #68, line #25019
# File #68, line #25020
# File #68, line #25021
# File #68, line #25022
# File #68, line #25023
# File #68, line #25024
# File #68, line #25025
# File #68, line #25026
# File #68, line #25027
# File #68, line #25028
# File #68, line #25029
# File #68, line #25030
# File #68, line #25031
# File #68, line #25032
# File #68, line #25033
# File #68, line #25034
# File #68, line #25035
# File #68, line #25036
# File #68, line #25037
# File #68, line #25038
# File #68, line #25039
# File #68, line #25040
# File #68, line #25041
# File #68, line #25042
# File #68, line #25043
# File #68, line #25044
# File #68, line #25045
# File #68, line #25046
# File #68, line #25047
# File #68, line #25048
# File #68, line #25049
# File #68, line #25050
# File #68, line #25051
# File #68, line #25052
# File #68, line #25053
# File #68, line #25054
# File #68, line #25055
# File #68, line #25056
# File #68, line #25057
# File #68, line #25058
# File #68, line #25059
# File #68, line #25060
# File #68, line #25061
# File #68, line #25062
# File #68, line #25063
# File #68, line #25064
# File #68, line #25065
# File #68, line #25066
# File #68, line #25067
# File #68, line #25068
# File #68, line #25069
# File #68, line #25070
# File #68, line #25071
# File #68, line #25072
# File #68, line #25073
# File #68, line #25074
# File #68, line #25075
# File #68, line #25076
# File #68, line #25077
# File #68, line #25078
# File #68, line #25079
# All .jsonl files combined into: ../data/stage_04_5/processed/combined_output.jsonl

# %% [markdown]
# ## 4.5.8. Extract results and save

# %% [markdown]
# Parse `combined_output.jsonl` — navigate the nested Batch API response structure to extract `original` (raw region string) and `region` (standardised English oblast name) from each function-call result. Deduplicate on `original`, inspect the region distribution, then **save** the final merged DB back to `region_db.pkl`.
#
# > The last cell (`final_df.to_pickle(...)`) is commented out as a safety guard — uncomment it only when you are satisfied with the results.
#
# **Output columns of `region_db.pkl`:**
#
# | Column | Description |
# |--------|-------------|
# | `original` | Raw region string from the job board (Cyrillic / transliterated) |
# | `region` | Standardised English oblast name (e.g. `"Kyiv Oblast"`) |

# %%
with open(output_file, 'r') as file:
    data = [json.loads(line) for line in file]

    records = []
    for entry in data:
        choices = entry.get('response', {}).get('body', {}).get('choices', [])
        if choices:
            message = choices[0].get('message', {})
            function_call = message.get('function_call', {})
            arguments_json = function_call.get('arguments')

            if arguments_json:
                arguments = json.loads(arguments_json)
                records.append({
                    'original': arguments.get('original'),
                    'city': arguments.get('city'),
                    'district': arguments.get('district'),
                    'region': arguments.get('region'),
                    'country': arguments.get('country'),
                    "latitude": arguments.get("latitude"),
                    "longitude": arguments.get("longitude",),
                    'is_remote': arguments.get('is_remote')})

    final_df = pd.DataFrame(records)
    final_df = final_df.astype({
        "original" : str,
        "city" : str,
        "region" : str,
        "district" : str,
        "country" : str,
        "latitude" : str,
        "longitude" : str,
        "is_remote" : str
    })

final_df.tail()
# Out:
#                                         original     city  \
# 25074  Поповка, Маньковский р-н, Черкасская обл.  Popivka
# 25075                    Древини, Волынская обл.  Drevyny
# 25076                                        NaN
# 25077                   Львов, Шевченковский р-н     Lviv
# 25078                                        NaN
#
#                        district           region  country latitude longitude  \
# 25074       Mankivskyi District  Cherkasy Oblast  Ukraine  48.8892   30.3931
# 25075                               Volyn Oblast  Ukraine  51.5667   25.0667
# 25076
# 25077  Shevchenkivskyi District      Lviv Oblast  Ukraine  49.8397   24.0297
# 25078
#
#       is_remote
# 25074     false
# 25075     false
# 25076     false
# 25077     false
# 25078     false

# %%
final_df.drop_duplicates(subset=['original'], keep="first", inplace=True)
final_df
# Out:
#                                           original          city  \
# 0                                            Odesa         Odesa
# 1                                             Sumy          Sumy
# 2                                     Khmelnytskyi  Khmelnytskyi
# 3                                          Kharkiv       Kharkiv
# 4                                         Uzhhorod      Uzhhorod
# ...                                            ...           ...
# 25070                     Надітичі, Львовская обл.     Naditychi
# 25073  Успеновка, Бердянский р-н, Запорожская обл.     Uspenovka
# 25074    Поповка, Маньковский р-н, Черкасская обл.       Popivka
# 25075                      Древини, Волынская обл.       Drevyny
# 25077                     Львов, Шевченковский р-н          Lviv
#
#                        district               region  country latitude  \
# 0                                       Odesa Oblast  Ukraine  46.4825
# 1                                        Sumy Oblast  Ukraine  50.9077
# 2                                Khmelnytskyi Oblast  Ukraine  49.4216
# 3                                     Kharkiv Oblast  Ukraine  49.9935
# 4                                 Zakarpattia Oblast  Ukraine  48.6208
# ...                         ...                  ...      ...      ...
# 25070                                    Lviv Oblast  Ukraine  49.6681
# 25073        Berdyansk District  Zaporizhzhia Oblast  Ukraine  46.8667
# 25074       Mankivskyi District      Cherkasy Oblast  Ukraine  48.8892
# 25075                                   Volyn Oblast  Ukraine  51.5667
# 25077  Shevchenkivskyi District          Lviv Oblast  Ukraine  49.8397
#
#       longitude is_remote
# 0       30.7233     false
# 1       34.7981     false
# 2       26.9965     false
# 3       36.2304     false
# 4       22.2879     false
# ...         ...       ...
# 25070   23.9306     false
# 25073   36.8667     false
# 25074   30.3931     false
# 25075   25.0667     false
# 25077   24.0297     false
#
# [14716 rows x 8 columns]

# %%
region_counts = final_df['region'].value_counts()
region_counts_df = region_counts.reset_index()
region_counts_df.columns = ['Region', 'Count']
region_counts_df = region_counts_df.sort_values('Region')
region_counts_df
# Out:
#                    Region  Count
# 25                            60
# 40  Al Asimah Governorate      1
# 58                 Berlin      1
# 54      Bratislava Region      1
# 62       Central Bohemian      1
# ..                    ...    ...
# 18    Zaporizhzhia Oblast    470
# 2         Zhytomyr Oblast    835
# 38                 remote      2
# 60          Île-de-France      1
# 33       Łódź Voivodeship      3
#
# [66 rows x 2 columns]

# %%
final_df.to_pickle(g.Config.STAGE4_5_REGION_DB_PATH)

# %% [markdown]
# ---
# © 2026 Yurii Kleban, Britta Rude. All rights reserved.
