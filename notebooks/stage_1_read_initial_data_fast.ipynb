# %% [markdown]
# ## Stage 1 — Load and assemble raw job vacancy data
#
# **Role:** Entry point of the pipeline. Reads all raw daily JSON snapshots from `data/input/`, deduplicates records, cleans text, detects languages, and builds the processed dataset used by all downstream stages.
#
# **Position:** This is the only notebook in Stage 1 required for the demo pipeline. Run it before any Stage 2 notebooks.
#
# **Must be run manually** after placing input JSON files in `data/input/`.

# %% [markdown]
# ### Initialisation
#
# Empty cell reserved for kernel warm-up.

# %% [markdown]
# ## 1.1. Description

# %% [markdown]
# The first stage of the pipeline focuses on reading raw JSON files containing job advertisement data, cleaning up their textual content, and filtering new, unique records based on advertisement IDs. This step prepares the dataset for downstream processing tasks such as skill extraction and language classification.

# %% [markdown]
# ## 1.2. Packages and configuration

# %% [markdown]
# Cleaning a memory of Jupyter Notebook before run:

# %% [markdown]
# Load the autoreload extension so that changes to `general.py` and `stage1.py` are picked up automatically without restarting the kernel. Append `../code/` to the Python path so the shared modules can be imported. Call `g.clean_memory()` to release any variables left from a previous run.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../code")
import pandas as pd
import os
import general as g
g.clean_memory()
import stage1 as st1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Checking working directory:

# %% [markdown]
# Verify the working directory. The notebook must run from the `notebooks/` folder so that relative paths in `.env` (e.g. `../data/input`) resolve correctly.

# %%
# %pwd
# Out:
# 'G:\\mendely-paper-repository\\notebooks'

# %% [markdown]
# ## 1.2. Create list of processing files

# %% [markdown]
# Build or update the Stage 1 process tracker. Scans `data/input/` for JSON files and creates one row per file with columns tracking clean status and output paths. If the tracker pickle already exists, only newly added files are appended. The resulting DataFrame is displayed to confirm which files are registered.

# %%
process_stage_df = st1.update_stage1_process_data(g.Config.INPUT_PATH, g.Config.STAGE1_PROCESS_PATH)
process_stage_df
# Out:
#       input_file                        input_path clean_path clean_status  \
# 0  ua-2024-01-01  ../data/input\ua-2024-01-01.json       None         None
#
#   id_region_path id_region_status
# 0           None             None

# %% [markdown]
# Retrieve the list of files that have not yet been processed (i.e. `clean_status` is NaN). This list drives the processing loop below.

# %%
files = st1.get_not_processed_files(process_stage_df)
files
# Out:
# ['ua-2024-01-01']

# %% [markdown]
# Sanity check: if `True`, all files have already been processed and the loop below will be skipped.

# %%
files[0] is None
# Out:
# False

# %% [markdown]
# Local override of the `clean_data_duplicates` function. Groups records by title, description, salary, and region to collapse duplicates, keeping the first ID and dates while averaging click counts across duplicate listings.

# %%
def clean_data_duplicates(dtx):

    aggregated_by_few_cols = dtx.groupby(['title', 'description', 'min_salary', 'max_salary', 'region'], dropna=False).agg(
        {
            'id': 'first',
            'date_created': 'first',
            'date_expired': 'first',
            'salary_rate': 'first',
            'currency': 'first',
            'number_of_clicks': 'mean'
        }).reset_index()

    aggregated_by_few_cols = aggregated_by_few_cols[dtx.columns]

    return aggregated_by_few_cols

# %% [markdown]
# Ensure that the Stage 1 output folders exist before writing any files. Creates `processed/output/` and `intermediate/id_region_click/` if they are missing.

# %%
g.check_folder_exists(g.Config.STAGE1_OUTPUT_PATH)
g.check_folder_exists(g.Config.STAGE1_ID_REGION_NCLICK_PATH)

# %% [markdown]
# Main processing loop. Iterates over all unprocessed input files and runs the full Stage 1 pipeline for each:
#
# 1. Reads the raw JSON and normalises dates
# 2. Deduplicates records by key fields
# 3. Saves the id/region/clicks snapshot
# 4. Filters to only new job IDs not seen in previous files
# 5. Cleans text (removes dates, salaries, emoji, normalises characters)
# 6. Detects and filters by language (keeps: en, uk, ru, cs, pl)
# 7. Updates the global unique ID database
# 8. Saves the cleaned output pickle and marks the file as complete in the tracker

# %%
if files[0] is not None:
    for f_name in files:
        process_df = st1.update_stage1_process_data(g.Config.INPUT_PATH, g.Config.STAGE1_PROCESS_PATH)
        st1.preprocess_file(process_df, f_name, g.Config)
        print(f"Completed: {f_name}")
# Out:
# ---------------- Preprocessing file: ../data/input\ua-2024-01-01.json
# > initial rows: 100
# > unique rows: 100
# > unique rows: 0
# > new unique ids: 100
# > data cleaned:100
# > detecting languages + removed not allowed: 100
# > unique rows before: 0
# > unique rows after: 100
# > id_region file path:../data/stage_01/intermediate/id_region_click\ua-2024-01-01.pkl
# Completed: ua-2024-01-01

# %% [markdown]
# ## Clean regional data

# %% [markdown]
# Reload the completed process tracker from disk. At this point all files should have `clean_status = complete` or `empty`. The tracker is displayed to confirm processing is finished before the regional cleanup step.

# %%
process_stage_df = pd.read_pickle(g.Config.STAGE1_PROCESS_PATH)
process_stage_df
# Out:
#       input_file                        input_path  \
# 0  ua-2024-01-01  ../data/input\ua-2024-01-01.json
#
#                                           clean_path clean_status  \
# 0  ../data/stage_01/processed/output\ua-2024-01-0...     complete
#
#                                       id_region_path id_region_status
# 0  ../data/stage_01/intermediate/id_region_click\...         complete

# %% [markdown]
# Reload the completed process tracker from disk. At this point all files should have `clean_status = complete` or `empty`. The tracker is displayed to confirm processing is finished before the regional cleanup step.

# %%
for _, row in process_stage_df.iterrows():

    rejoin_done = None
    rejoin = None
    missing = None

    input_df = pd.read_json(row["input_path"])

    id_region_df = pd.read_pickle(row["id_region_path"])

    print(f"{_}-{row["input_path"]}-----------------")
    print(f"INIT REGION: {id_region_df.shape[0]}")
    if os.path.exists(row["clean_path"]):
        clean_df = pd.read_pickle(row["clean_path"])
        rejoin = id_region_df.merge(clean_df, on=["id"], how="left")
        rejoin_done = rejoin.dropna(subset=["clean_title"])
        missing = rejoin[rejoin["clean_title"].isnull()]
    else:
        rejoin = id_region_df
        missing = rejoin

    missing = missing.dropna(axis=1, how='all')

    if missing.shape[0] == 0:
        continue

    date = st1.extract_date_from_file_name(row["input_file"])

    for __, _row in process_stage_df[0:_].iterrows():

        if not os.path.exists(_row["clean_path"]):
            continue

        clean_df = pd.read_pickle(_row["clean_path"])

        rejoin = missing.merge(clean_df, on=["id"], how="left")
        #print(f"{_row["input_file"]} - rejoin: {rejoin.shape[0]}")

        if rejoin.shape[0] > 0:
            done = rejoin.dropna(subset=["clean_title"])

            missing = rejoin[rejoin["clean_title"].isnull()]
            if done.shape[0] > 0:
                rejoin_done = pd.concat([rejoin_done, done], ignore_index=True)
            if missing.shape[0] == 0:
                continue

            missing = missing.dropna(axis=1, how='all')

    key_cols = ["id", "region", "number_of_clicks", "date"]
    if missing.shape[0] > 0:
        id_region_df = id_region_df.merge(missing[key_cols], on=key_cols, how='left', indicator=True)
        id_region_df = id_region_df[id_region_df['_merge'] == 'left_only'].drop(columns=['_merge'])
        id_region_df.to_pickle(row["id_region_path"])
    print(f"FINAL REGION: {id_region_df.shape[0]}\n")
# Out:
# 0-../data/input\ua-2024-01-01.json-----------------
# INIT REGION: 100

# %%
pd.read_pickle("../data/stage_01/processed/output/ua-2024-01-01.pkl")
# Out:
#                      id              title  \
# 0   2673941879650338041         Accountant
# 1   2829269335131763744         Accountant
# 2   2292953494970979965         Accountant
# 3   8991901255055716088  Backend Developer
# 4   9937412981206494120   Business Analyst
# ..                  ...                ...
# 95  5682536959350677812  Warehouse Manager
# 96  4745382362973408538  Warehouse Manager
# 97  1748822233724604818  Warehouse Manager
# 98  5942472651725435914  Warehouse Manager
# 99  4891541965315671145  Warehouse Manager
#
#                                           description  min_salary  max_salary  \
# 0   Our company is seeking a motivated individual ...     50000.0     57000.0
# 1   We are expanding our team and looking for a de...         NaN         NaN
# 2   We are looking for an experienced professional...     21000.0     40000.0
# 3   Looking for a proactive team player to support...         NaN         NaN
# 4   Opportunity to work with cutting-edge technolo...         NaN         NaN
# ..                                                ...         ...         ...
# 95  Exciting opportunity for a skilled professiona...         NaN         NaN
# 96  Looking for a proactive team player to support...         NaN         NaN
# 97  Seeking an experienced professional with stron...         NaN         NaN
# 98  We are expanding our team and looking for a de...         NaN         NaN
# 99  We are looking for an experienced professional...         NaN         NaN
#
#    currency salary_rate date_created date_expired        clean_title  \
# 0       EUR      hourly   2024-01-01   2024-02-26         accountant
# 1      None        None   2024-01-01   2024-01-30         accountant
# 2       EUR     monthly   2024-01-01   2024-02-19         accountant
# 3      None        None   2024-01-01   2024-02-07  backend developer
# 4      None        None   2024-01-01   2024-02-14   business analyst
# ..      ...         ...          ...          ...                ...
# 95     None        None   2024-01-01   2024-02-16  warehouse manager
# 96     None        None   2024-01-01   2024-02-21  warehouse manager
# 97      UAH     monthly   2024-01-01   2024-02-28  warehouse manager
# 98      UAH      hourly   2024-01-01   2024-02-17  warehouse manager
# 99     None        None   2024-01-01   2024-02-16  warehouse manager
#
#                                            clean_desc title_lang desc_lang
# 0   our company is seeking a motivated individual ...         en        en
# 1   we are expanding our team and looking for a de...         en        en
# 2   we are looking for an experienced professional...         en        en
# 3   looking for a proactive team player to support...         en        en
# 4   opportunity to work with cutting-edge technolo...         en        en
# ..                                                ...        ...       ...
# 95  exciting opportunity for a skilled professiona...         en        en
# 96  looking for a proactive team player to support...         en        en
# 97  seeking an experienced professional with stron...         en        en
# 98  we are expanding our team and looking for a de...         en        en
# 99  we are looking for an experienced professional...         en        en
#
# [100 rows x 13 columns]

# %% [markdown]
# ---
# © 2026 Yurii Kleban, Britta Rude. All rights reserved.
